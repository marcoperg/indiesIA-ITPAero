# %%
TARGET_AXIS = 'X'
assert TARGET_AXIS in ('X', 'Z', 'B', 'C')

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, StratifiedGroupKFold, TimeSeriesSplit
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostRegressor
from tqdm.auto import tqdm
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("ITPAero_dataset.csv", sep=';')
df['FBrochado'] = pd.to_datetime(df['FBrochado'])

# %%
df['target'] = df[f'{TARGET_AXIS}CMM'] + df[f'{TARGET_AXIS}C']

df['targetX'] = df[f'XCMM'] + df[f'XC']
df['targetZ'] = df[f'ZCMM'] + df[f'ZC']
df['targetB'] = df[f'BCMM'] + df[f'BC']
df['targetC'] = df[f'CCMM'] + df[f'CC']

# %%
df = df[df.target.isna() == False]

# %%
def time_series_feature_engineering(df):
    """
    Perform feature engineering on time series data.
    
    Parameters:
    df (pd.DataFrame): Input DataFrame
    target_column (str): Name of the target variable column
    date_column (str): Name of the date column
    window_sizes (list): List of rolling window sizes (default: [7, 14, 30])
    
    Returns:
    pd.DataFrame: DataFrame with new engineered features
    """
    
    for window in [3, 7, 14, 30]:
        # Rolling mean
        df[f'{group}{target_column}_rolling_mean{window}'] = df[target_column].rolling(window=window).mean().shift(1)
        
        # Rolling standard deviation
        df[f'{group}{target_column}_rolling_std{window}'] = df[target_column].rolling(window=window).std().shift(1)
        
        # Rolling median
        df[f'{group}{target_column}_rolling_median{window}'] = df[target_column].rolling(window=window).median().shift(1)
        
        # Rolling min
        df[f'{group}{target_column}_rolling_min{window}'] = df[target_column].rolling(window=window).min().shift(1)
        
        # Rolling max
        df[f'{group}{target_column}_rolling_max{window}'] = df[target_column].rolling(window=window).max().shift(1)
        
        # Rolling skewness
        df[f'{group}{target_column}_rolling_skew{window}'] = df[target_column].rolling(window=window).skew().shift(1)
        
        # Rolling kurtosis
        df[f'{group}{target_column}_rolling_kurtosis{window}'] = df[target_column].rolling(window=window).kurt().shift(1)
        
        # Exponential moving average
        df[f'{group}{target_column}_ema{window}'] = df[target_column].ewm(span=window, adjust=False).mean().shift(1)
    
    # Lag features
    for lag in [1, 3, 7, 14, 30]:
        df[f'{group}{target_column}_lag{lag}'] = df[target_column].shift(lag)
    
    # Reset index to bring date column back
#    df = df.reset_index(drop)
    
    return df

df["BrochaSN_Utillaje"] = str(df["BrochaSN"]) + str(df[" Utillaje"])
df["BrochaSN_NBrochasHSS"] = str(df["BrochaSN"]) + str(df["NBrochasHSS"])
df["BrochaSN_ndisco"] = str(df["BrochaSN"]) + str(df["NDisco"])
df["Brocha_ndisco"] = str(df["Brocha"]) + str(df["NDisco"])
df["Maquina_BrochaSN_NBrochasHSS"] = str(df["Maquina"]) + str(df["BrochaSN_NBrochasHSS"])
df["Maquina_BrochaSN"] = str(df["Maquina"]) + str(df["BrochaSN"])


for target_column in ['targetX', 'targetZ', 'targetB', 'targetC']:
    for group in ['BrochaSN_Utillaje',
                  'Maquina',
                  ' Utillaje', 
                  'Brocha',
                  'Brocha_ndisco',
                  'Maquina_BrochaSN',
                  'BrochaSN_ndisco',
                  'BrochaSN',
                  'BrochaSN_NBrochasHSS', 
                  'Maquina_BrochaSN_NBrochasHSS']:

        df = df.groupby(group, group_keys=False).apply(time_series_feature_engineering)

# %%
# Convert all object columns to categorical
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype('category')

# %%
train_idx = df['FBrochado'] < '2024-7-1'
test_idx = df['FBrochado'] >= '2024-7-1'

# %%
df['FBrochado'] = df['FBrochado'].astype('int')

# %%
# Important after FE
df = df[df.DUMMY == 'FALSO']

# %%
df = df.drop(columns=[
    'XCMM',
    'ZCMM',
    'BCMM',
    'CCMM',
    'BrochaSN',
    'PartNumber',
    'FBrochado',
    'XC',
    'ZC',
    'BC',
    'CC',
    'OrdenFabricacion'])

# %%
df_train = df[train_idx]
df_test = df[test_idx]
# Out:
# /var/folders/th/h_b6fb4s5kx77mr9j442kbh80000gn/T/ipykernel_90758/1766937709.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_train = df[train_idx]
# /var/folders/th/h_b6fb4s5kx77mr9j442kbh80000gn/T/ipykernel_90758/1766937709.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_test = df[test_idx]

# %%
y = df_train['target']
X = df_train.drop(columns=['target', 'targetX', 'targetZ', 'targetB', 'targetC'])

# %%
y_test = df_test['target']
X_test = df_test.drop(columns=['target', 'targetX', 'targetZ', 'targetB', 'targetC'])

# %%
cat_cols = X.dtypes[X.dtypes == 'category'].index.tolist()

# %%
class VotingModel(BaseEstimator, RegressorMixin):
    #weights = np.arange(1, len(y_preds) + 1)
    #weights = np.ones_like(y_preds)
    #weights = np.exp(np.linspace(0, 2, len(y_preds)))
    #weights = np.linspace(1, len(y_preds), len(y_preds)) ** 2
    #weights = np.linspace(1, len(y_preds), len(y_preds)) ** 3
    #weights = np.linspace(1, len(y_preds), len(y_preds)) ** 4
    #weights = np.linspace(1, len(y_preds), len(y_preds)) ** 5


    #weights = np.log(np.linspace(1, len(y_preds) + 1, len(y_preds)))
    #x = np.linspace(-6, 6, len(y_preds))
    #weights = 1 / (1 + np.exp(-x))

    def __init__(self, estimators):
        super().__init__()
        self.estimators = estimators
        
    def fit(self, X, y=None):
        return self
    
    def predict_sep(self, X):
        y_preds_lgbm = [estimator['lgbm'].predict(X) for estimator in self.estimators]
        y_preds_xgb = [estimator['xgb'].predict(X) for estimator in self.estimators]
        y_preds_cat = [estimator['cat'].predict(X) for estimator in self.estimators]

        
        weights = np.linspace(1, len(y_preds_cat), len(y_preds_cat)) ** 5

        lgbm_avg = np.average(y_preds_lgbm, weights=weights, axis=0)
        xgb_avg = np.average(y_preds_xgb, weights=weights, axis=0)
        cat_avg = np.average(y_preds_cat, weights=weights, axis=0)

        return lgbm_avg, xgb_avg, cat_avg
    

    def predict(self, X):
        y_preds_lgbm = [estimator['lgbm'].predict(X) for estimator in self.estimators]
        y_preds_xgb = [estimator['xgb'].predict(X) for estimator in self.estimators]
        y_preds_cat = [estimator['cat'].predict(X) for estimator in self.estimators]

        y_preds = np.mean([y_preds_lgbm, y_preds_cat], axis=0)
        
        weights = np.linspace(1, len(y_preds), len(y_preds)) ** 5

        return np.average(y_preds, weights=weights, axis=0)

# %%
def train(params):
    n_splits = 5
    tscv = TimeSeriesSplit(n_splits=n_splits, test_size=100)
    fitted_models = []
    rmses = []
    max_abss = []

    for i, (train_index, test_index) in enumerate(tqdm(tscv.split(X), total=n_splits)):
        X_train, y_train = X.iloc[train_index], y.iloc[train_index]
        X_valid, y_valid = X.iloc[test_index], y.iloc[test_index]

        modelLGBM = lgb.LGBMRegressor(**params)
        modelXGB = xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=1000,
            max_depth=4,
            learning_rate=0.1,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42,
            enable_categorical=True,
        )
        
        modelCat = CatBoostRegressor(
            iterations=1000,
            learning_rate=0.1,
            depth=6,
            loss_function='RMSE',
            eval_metric='RMSE',
            random_seed=0,
            early_stopping_rounds=50,
            verbose=0
        )

        modelCat.fit(
            X_train,
            y_train,
            eval_set=(X_valid, y_valid),
            # use_best_model=True,
            cat_features=cat_cols,  # Pass the list of categorical column indices
        )

        modelXGB.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
        )

        modelLGBM.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            #callbacks=[lgb.log_evaluation(200), lgb.early_stopping(60)]
            callbacks=[lgb.early_stopping(50, verbose=False)]
        )
        
        fitted_models.append({'lgbm': modelLGBM, 'xgb': modelXGB, 'cat': modelCat})

        y_pred_valid = np.mean([modelLGBM.predict(X_valid), 
                                modelXGB.predict(X_valid)], axis=0)
        rmse = root_mean_squared_error(y_valid, y_pred_valid)
        max_abs = max(abs(y_valid - y_pred_valid))
        rmses.append(rmse)
        max_abss.append(max_abs)

    model = VotingModel(fitted_models)

    return model, rmses, max_abss

# %% [markdown]
# # Polbo galego

# %%
import joblib

# Create or load the study
def create_or_load_study(study_name, storage=None):
    try:
        study = joblib.load(f"optuna/{study_name}.pkl")
        print(f"Loaded study '{study_name}' from file.")
    except FileNotFoundError:
        study = optuna.create_study(study_name=study_name, storage=storage, direction='maximize')
        print(f"Created new study '{study_name}'.")
    return study

# Function to save the study
def save_study(study, study_name):
    joblib.dump(study, f"optuna/{study_name}.pkl")
    print(f"Study '{study_name}' saved to file.")

# %%
def objective(trial):
    # set up the parameters to be optimized
    param = {
        'metric': 'rmse', 
        #'random_state': seed,
        'n_estimators': 10000,
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-4, 10.0,log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-4, 10.0,log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2,log=True),
        'max_depth': trial.suggest_int('max_depth', 4, 8),
        'num_leaves': trial.suggest_int('num_leaves', 40, 100),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
        'cat_smooth': trial.suggest_int('cat_smooth', 1, 100),
        'force_col_wise':True,
        'min_data_in_leaf': 30,
        'verbose': -1
    }

    model, rmses, max_abss = train(param)
    #y_pred = model.predict(X_test,)
    #return root_mean_squared_error(y_test, y_pred)
    return np.mean(rmses)

# %%
import optuna
study_name = f'optuna-{TARGET_AXIS}'
study = create_or_load_study(study_name)

def print_callback(study, trial):
    print(f"Current value: {trial.value}, Current params: {trial.params}")
    #print(f"Best value: {study.best_value}, Best params: {trial.best_trial.params}")

    study_df = study.trials_dataframe()
    save_study(study, study_name)
    study_df.to_csv('optuna.csv', index=False)


#study.optimize(objective, n_trials=50, callbacks=[print_callback])
# Out:
# Loaded study 'optuna-X' from file.

# %%
study.best_params
# Out:
# {'reg_alpha': 9.563614073230701,
#  'reg_lambda': 2.0037425474007504,
#  'colsample_bytree': 0.3724836970198203,
#  'subsample': 0.5450904836262437,
#  'learning_rate': 0.00829142573909476,
#  'max_depth': 7,
#  'num_leaves': 81,
#  'min_child_samples': 32,
#  'cat_smooth': 99}

# %%
good_params = {
    'metric': 'rmse',
    'n_estimators': 10000,
'reg_alpha': 0.009276932353966864, 'reg_lambda': 0.0009662650305581986, 'colsample_bytree': 0.6698903262487423, 'subsample': 0.6732087036287323, 'learning_rate': 0.01254395613011985, 'max_depth': 6, 'num_leaves': 68, 'min_child_samples': 29, 'cat_smooth': 46,    'cat_smooth': 6,
    'force_col_wise':True,
    'min_data_in_leaf': 30,
    'verbose': -1
}

# %%
params = {
    'metric': 'rmse',
    'n_estimators': 10000,
    'verbose': -1,
    **study.best_params
}

model, rmses, max_abss = train(params)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# [0]	validation_0-rmse:0.38050
# [1]	validation_0-rmse:0.35354
# [2]	validation_0-rmse:0.33406
# [3]	validation_0-rmse:0.31766
# [4]	validation_0-rmse:0.30146
# [5]	validation_0-rmse:0.28618
# [6]	validation_0-rmse:0.27505
# [7]	validation_0-rmse:0.26175
# [8]	validation_0-rmse:0.24961
# [9]	validation_0-rmse:0.24085
# [10]	validation_0-rmse:0.23216
# [11]	validation_0-rmse:0.22284
# [12]	validation_0-rmse:0.21922
# [13]	validation_0-rmse:0.21425
# [14]	validation_0-rmse:0.20997
# [15]	validation_0-rmse:0.20394
# [16]	validation_0-rmse:0.20057
# [17]	validation_0-rmse:0.19693
# [18]	validation_0-rmse:0.19628
# [19]	validation_0-rmse:0.19492
# [20]	validation_0-rmse:0.19269
# [21]	validation_0-rmse:0.19056
# [22]	validation_0-rmse:0.18957
# [23]	validation_0-rmse:0.18826
# [24]	validation_0-rmse:0.18763
# [25]	validation_0-rmse:0.18689
# [26]	validation_0-rmse:0.18649
# [27]	validation_0-rmse:0.18546
# [28]	validation_0-rmse:0.18452
# [29]	validation_0-rmse:0.18355
# [30]	validation_0-rmse:0.18206
# [31]	validation_0-rmse:0.18177
# [32]	validation_0-rmse:0.18111
# [33]	validation_0-rmse:0.18127
# [34]	validation_0-rmse:0.18014
# [35]	validation_0-rmse:0.18031
# [36]	validation_0-rmse:0.17981
# [37]	validation_0-rmse:0.18014
# [38]	validation_0-rmse:0.17817
# [39]	validation_0-rmse:0.17695
# [40]	validation_0-rmse:0.17643
# [41]	validation_0-rmse:0.17606
# [42]	validation_0-rmse:0.17580
# [43]	validation_0-rmse:0.17712
# [44]	validation_0-rmse:0.17689
# [45]	validation_0-rmse:0.17653
# [46]	validation_0-rmse:0.17783
# [47]	validation_0-rmse:0.17807
# [48]	validation_0-rmse:0.17631
# [49]	validation_0-rmse:0.17579
# [50]	validation_0-rmse:0.17626
# [51]	validation_0-rmse:0.17674
# [52]	validation_0-rmse:0.17713
# [53]	validation_0-rmse:0.17674
# [54]	validation_0-rmse:0.17726
# [55]	validation_0-rmse:0.17698
# [56]	validation_0-rmse:0.17783
# [57]	validation_0-rmse:0.17771
# [58]	validation_0-rmse:0.17753
# [59]	validation_0-rmse:0.17677
# [60]	validation_0-rmse:0.17723
# [61]	validation_0-rmse:0.17794
# [62]	validation_0-rmse:0.17841
# [63]	validation_0-rmse:0.18065
# [64]	validation_0-rmse:0.18093
# [65]	validation_0-rmse:0.18110
# [66]	validation_0-rmse:0.18131
# [67]	validation_0-rmse:0.18103
# [68]	validation_0-rmse:0.18045
# [69]	validation_0-rmse:0.18040
# [70]	validation_0-rmse:0.18081
# [71]	validation_0-rmse:0.18087
# [72]	validation_0-rmse:0.18158
# [73]	validation_0-rmse:0.18221
# [74]	validation_0-rmse:0.18327
# [75]	validation_0-rmse:0.18397
# [76]	validation_0-rmse:0.18416
# [77]	validation_0-rmse:0.18413
# [78]	validation_0-rmse:0.18427
# [79]	validation_0-rmse:0.18554
# [80]	validation_0-rmse:0.18569
# [81]	validation_0-rmse:0.18626
# [82]	validation_0-rmse:0.18658
# [83]	validation_0-rmse:0.18694
# [84]	validation_0-rmse:0.18626
# [85]	validation_0-rmse:0.18604
# [86]	validation_0-rmse:0.18674
# [87]	validation_0-rmse:0.18642
# [88]	validation_0-rmse:0.18685
# [89]	validation_0-rmse:0.18655
# [90]	validation_0-rmse:0.18670
# [91]	validation_0-rmse:0.18583
# [92]	validation_0-rmse:0.18579
# [93]	validation_0-rmse:0.18550
# [94]	validation_0-rmse:0.18558
# [95]	validation_0-rmse:0.18572
# [96]	validation_0-rmse:0.18596
# [97]	validation_0-rmse:0.18545
# [98]	validation_0-rmse:0.18631
# [99]	validation_0-rmse:0.18666
# [100]	validation_0-rmse:0.18674
# [101]	validation_0-rmse:0.18673
# [102]	validation_0-rmse:0.18716
# [103]	validation_0-rmse:0.18729
# [104]	validation_0-rmse:0.18774
# [105]	validation_0-rmse:0.18787
# [106]	validation_0-rmse:0.18773
# [107]	validation_0-rmse:0.18822
# [108]	validation_0-rmse:0.18797
# [109]	validation_0-rmse:0.18888
# [110]	validation_0-rmse:0.18905
# [111]	validation_0-rmse:0.18919
# [112]	validation_0-rmse:0.18871
# [113]	validation_0-rmse:0.18872
# [114]	validation_0-rmse:0.18858
# [115]	validation_0-rmse:0.18897
# [116]	validation_0-rmse:0.18912
# [117]	validation_0-rmse:0.18892
# [118]	validation_0-rmse:0.18909
# [119]	validation_0-rmse:0.18910
# [120]	validation_0-rmse:0.18911
# [121]	validation_0-rmse:0.18950
# [122]	validation_0-rmse:0.18959
# [123]	validation_0-rmse:0.18935
# [124]	validation_0-rmse:0.18914
# [125]	validation_0-rmse:0.18912
# [126]	validation_0-rmse:0.18922
# [127]	validation_0-rmse:0.18980
# [128]	validation_0-rmse:0.18980
# [129]	validation_0-rmse:0.18920
# [130]	validation_0-rmse:0.18878
# [131]	validation_0-rmse:0.18830
# [132]	validation_0-rmse:0.18825
# [133]	validation_0-rmse:0.18819
# [134]	validation_0-rmse:0.18808
# [135]	validation_0-rmse:0.18810
# [136]	validation_0-rmse:0.18819
# [137]	validation_0-rmse:0.18878
# [138]	validation_0-rmse:0.18869
# [139]	validation_0-rmse:0.18878
# [140]	validation_0-rmse:0.18859
# [141]	validation_0-rmse:0.18867
# [142]	validation_0-rmse:0.18865
# [143]	validation_0-rmse:0.18900
# [144]	validation_0-rmse:0.18912
# [145]	validation_0-rmse:0.18923
# [146]	validation_0-rmse:0.18929
# [147]	validation_0-rmse:0.18897
# [148]	validation_0-rmse:0.18880
# [149]	validation_0-rmse:0.18855
# [150]	validation_0-rmse:0.18889
# [151]	validation_0-rmse:0.18911
# [152]	validation_0-rmse:0.18889
# [153]	validation_0-rmse:0.18883
# [154]	validation_0-rmse:0.18878
# [155]	validation_0-rmse:0.18877
# [156]	validation_0-rmse:0.18935
# [157]	validation_0-rmse:0.18929
# [158]	validation_0-rmse:0.18909
# [159]	validation_0-rmse:0.18917
# [160]	validation_0-rmse:0.18920
# [161]	validation_0-rmse:0.18912
# [162]	validation_0-rmse:0.18920
# [163]	validation_0-rmse:0.18905
# [164]	validation_0-rmse:0.18895
# [165]	validation_0-rmse:0.18923
# [166]	validation_0-rmse:0.18930
# [167]	validation_0-rmse:0.18949
# [168]	validation_0-rmse:0.19000
# [169]	validation_0-rmse:0.18989
# [170]	validation_0-rmse:0.19000
# [171]	validation_0-rmse:0.19023
# [172]	validation_0-rmse:0.19034
# [173]	validation_0-rmse:0.19040
# [174]	validation_0-rmse:0.19044
# [175]	validation_0-rmse:0.19042
# [176]	validation_0-rmse:0.19102
# [177]	validation_0-rmse:0.19084
# [178]	validation_0-rmse:0.19104
# [179]	validation_0-rmse:0.19103
# [180]	validation_0-rmse:0.19088
# [181]	validation_0-rmse:0.19111
# [182]	validation_0-rmse:0.19112
# [183]	validation_0-rmse:0.19142
# [184]	validation_0-rmse:0.19140
# [185]	validation_0-rmse:0.19111
# [186]	validation_0-rmse:0.19145
# [187]	validation_0-rmse:0.19151
# [188]	validation_0-rmse:0.19174
# [189]	validation_0-rmse:0.19188
# [190]	validation_0-rmse:0.19171
# [191]	validation_0-rmse:0.19131
# [192]	validation_0-rmse:0.19164
# [193]	validation_0-rmse:0.19250
# [194]	validation_0-rmse:0.19233
# [195]	validation_0-rmse:0.19245
# [196]	validation_0-rmse:0.19228
# [197]	validation_0-rmse:0.19210
# [198]	validation_0-rmse:0.19213
# [199]	validation_0-rmse:0.19225
# [200]	validation_0-rmse:0.19208
# [201]	validation_0-rmse:0.19211
# [202]	validation_0-rmse:0.19205
# [203]	validation_0-rmse:0.19227
# [204]	validation_0-rmse:0.19219
# [205]	validation_0-rmse:0.19251
# [206]	validation_0-rmse:0.19242
# [207]	validation_0-rmse:0.19270
# [208]	validation_0-rmse:0.19256
# [209]	validation_0-rmse:0.19263
# [210]	validation_0-rmse:0.19270
# [211]	validation_0-rmse:0.19309
# [212]	validation_0-rmse:0.19317
# [213]	validation_0-rmse:0.19304
# [214]	validation_0-rmse:0.19290
# [215]	validation_0-rmse:0.19318
# [216]	validation_0-rmse:0.19309
# [217]	validation_0-rmse:0.19265
# [218]	validation_0-rmse:0.19305
# [219]	validation_0-rmse:0.19293
# [220]	validation_0-rmse:0.19305
# [221]	validation_0-rmse:0.19298
# [222]	validation_0-rmse:0.19291
# [223]	validation_0-rmse:0.19287
# [224]	validation_0-rmse:0.19278
# [225]	validation_0-rmse:0.19316
# [226]	validation_0-rmse:0.19342
# [227]	validation_0-rmse:0.19341
# [228]	validation_0-rmse:0.19341
# [229]	validation_0-rmse:0.19349
# [230]	validation_0-rmse:0.19314
# [231]	validation_0-rmse:0.19292
# [232]	validation_0-rmse:0.19299
# [233]	validation_0-rmse:0.19300
# [234]	validation_0-rmse:0.19299
# [235]	validation_0-rmse:0.19288
# [236]	validation_0-rmse:0.19291
# [237]	validation_0-rmse:0.19262
# [238]	validation_0-rmse:0.19275
# [239]	validation_0-rmse:0.19281
# [240]	validation_0-rmse:0.19290
# [241]	validation_0-rmse:0.19296
# [242]	validation_0-rmse:0.19294
# [243]	validation_0-rmse:0.19287
# [244]	validation_0-rmse:0.19276
# [245]	validation_0-rmse:0.19258
# [246]	validation_0-rmse:0.19284
# [247]	validation_0-rmse:0.19305
# [248]	validation_0-rmse:0.19309
# [249]	validation_0-rmse:0.19309
# [250]	validation_0-rmse:0.19320
# [251]	validation_0-rmse:0.19328
# [252]	validation_0-rmse:0.19352
# [253]	validation_0-rmse:0.19337
# [254]	validation_0-rmse:0.19347
# [255]	validation_0-rmse:0.19338
# [256]	validation_0-rmse:0.19345
# [257]	validation_0-rmse:0.19343
# [258]	validation_0-rmse:0.19344
# [259]	validation_0-rmse:0.19352
# [260]	validation_0-rmse:0.19348
# [261]	validation_0-rmse:0.19357
# [262]	validation_0-rmse:0.19386
# [263]	validation_0-rmse:0.19390
# [264]	validation_0-rmse:0.19389
# [265]	validation_0-rmse:0.19381
# [266]	validation_0-rmse:0.19391
# [267]	validation_0-rmse:0.19394
# [268]	validation_0-rmse:0.19407
# [269]	validation_0-rmse:0.19409
# [270]	validation_0-rmse:0.19392
# [271]	validation_0-rmse:0.19399
# [272]	validation_0-rmse:0.19416
# [273]	validation_0-rmse:0.19436
# [274]	validation_0-rmse:0.19456
# [275]	validation_0-rmse:0.19452
# [276]	validation_0-rmse:0.19456
# [277]	validation_0-rmse:0.19458
# [278]	validation_0-rmse:0.19453
# [279]	validation_0-rmse:0.19452
# [280]	validation_0-rmse:0.19447
# [281]	validation_0-rmse:0.19438
# [282]	validation_0-rmse:0.19434
# [283]	validation_0-rmse:0.19444
# [284]	validation_0-rmse:0.19440
# [285]	validation_0-rmse:0.19421
# [286]	validation_0-rmse:0.19441
# [287]	validation_0-rmse:0.19445
# [288]	validation_0-rmse:0.19445
# [289]	validation_0-rmse:0.19450
# [290]	validation_0-rmse:0.19439
# [291]	validation_0-rmse:0.19435
# [292]	validation_0-rmse:0.19432
# [293]	validation_0-rmse:0.19425
# [294]	validation_0-rmse:0.19439
# [295]	validation_0-rmse:0.19442
# [296]	validation_0-rmse:0.19440
# [297]	validation_0-rmse:0.19454
# [298]	validation_0-rmse:0.19446
# [299]	validation_0-rmse:0.19462
# [300]	validation_0-rmse:0.19463
# [301]	validation_0-rmse:0.19469
# [302]	validation_0-rmse:0.19478
# [303]	validation_0-rmse:0.19478
# [304]	validation_0-rmse:0.19471
# [305]	validation_0-rmse:0.19477
# [306]	validation_0-rmse:0.19481
# [307]	validation_0-rmse:0.19484
# [308]	validation_0-rmse:0.19482
# [309]	validation_0-rmse:0.19495
# [310]	validation_0-rmse:0.19497
# [311]	validation_0-rmse:0.19509
# [312]	validation_0-rmse:0.19521
# [313]	validation_0-rmse:0.19522
# [314]	validation_0-rmse:0.19516
# [315]	validation_0-rmse:0.19510
# [316]	validation_0-rmse:0.19524
# [317]	validation_0-rmse:0.19529
# [318]	validation_0-rmse:0.19535
# [319]	validation_0-rmse:0.19530
# [320]	validation_0-rmse:0.19554
# [321]	validation_0-rmse:0.19544
# [322]	validation_0-rmse:0.19546
# [323]	validation_0-rmse:0.19553
# [324]	validation_0-rmse:0.19553
# [325]	validation_0-rmse:0.19571
# [326]	validation_0-rmse:0.19578
# [327]	validation_0-rmse:0.19583
# [328]	validation_0-rmse:0.19590
# [329]	validation_0-rmse:0.19590
# [330]	validation_0-rmse:0.19591
# [331]	validation_0-rmse:0.19590
# [332]	validation_0-rmse:0.19594
# [333]	validation_0-rmse:0.19605
# [334]	validation_0-rmse:0.19612
# [335]	validation_0-rmse:0.19611
# [336]	validation_0-rmse:0.19608
# [337]	validation_0-rmse:0.19613
# [338]	validation_0-rmse:0.19624
# [339]	validation_0-rmse:0.19628
# [340]	validation_0-rmse:0.19625
# [341]	validation_0-rmse:0.19623
# [342]	validation_0-rmse:0.19628
# [343]	validation_0-rmse:0.19627
# [344]	validation_0-rmse:0.19629
# [345]	validation_0-rmse:0.19629
# [346]	validation_0-rmse:0.19640
# [347]	validation_0-rmse:0.19642
# [348]	validation_0-rmse:0.19642
# [349]	validation_0-rmse:0.19643
# [350]	validation_0-rmse:0.19644
# [351]	validation_0-rmse:0.19644
# [352]	validation_0-rmse:0.19646
# [353]	validation_0-rmse:0.19647
# [354]	validation_0-rmse:0.19647
# [355]	validation_0-rmse:0.19653
# [356]	validation_0-rmse:0.19657
# [357]	validation_0-rmse:0.19655
# [358]	validation_0-rmse:0.19653
# [359]	validation_0-rmse:0.19648
# [360]	validation_0-rmse:0.19646
# [361]	validation_0-rmse:0.19646
# [362]	validation_0-rmse:0.19637
# [363]	validation_0-rmse:0.19630
# [364]	validation_0-rmse:0.19639
# [365]	validation_0-rmse:0.19636
# [366]	validation_0-rmse:0.19636
# [367]	validation_0-rmse:0.19639
# [368]	validation_0-rmse:0.19648
# [369]	validation_0-rmse:0.19647
# [370]	validation_0-rmse:0.19650
# [371]	validation_0-rmse:0.19652
# [372]	validation_0-rmse:0.19660
# [373]	validation_0-rmse:0.19655
# [374]	validation_0-rmse:0.19654
# [375]	validation_0-rmse:0.19656
# [376]	validation_0-rmse:0.19654
# [377]	validation_0-rmse:0.19652
# [378]	validation_0-rmse:0.19651
# [379]	validation_0-rmse:0.19652
# [380]	validation_0-rmse:0.19650
# [381]	validation_0-rmse:0.19655
# [382]	validation_0-rmse:0.19663
# [383]	validation_0-rmse:0.19662
# [384]	validation_0-rmse:0.19667
# [385]	validation_0-rmse:0.19669
# [386]	validation_0-rmse:0.19670
# [387]	validation_0-rmse:0.19669
# [388]	validation_0-rmse:0.19680
# [389]	validation_0-rmse:0.19680
# [390]	validation_0-rmse:0.19675
# [391]	validation_0-rmse:0.19677
# [392]	validation_0-rmse:0.19674
# [393]	validation_0-rmse:0.19679
# [394]	validation_0-rmse:0.19678
# [395]	validation_0-rmse:0.19678
# [396]	validation_0-rmse:0.19670
# [397]	validation_0-rmse:0.19670
# [398]	validation_0-rmse:0.19672
# [399]	validation_0-rmse:0.19674
# [400]	validation_0-rmse:0.19679
# [401]	validation_0-rmse:0.19681
# [402]	validation_0-rmse:0.19676
# [403]	validation_0-rmse:0.19665
# [404]	validation_0-rmse:0.19670
# [405]	validation_0-rmse:0.19671
# [406]	validation_0-rmse:0.19673
# [407]	validation_0-rmse:0.19674
# [408]	validation_0-rmse:0.19671
# [409]	validation_0-rmse:0.19666
# [410]	validation_0-rmse:0.19668
# [411]	validation_0-rmse:0.19666
# [412]	validation_0-rmse:0.19665
# [413]	validation_0-rmse:0.19669
# [414]	validation_0-rmse:0.19679
# [415]	validation_0-rmse:0.19675
# [416]	validation_0-rmse:0.19672
# [417]	validation_0-rmse:0.19675
# [418]	validation_0-rmse:0.19680
# [419]	validation_0-rmse:0.19679
# [420]	validation_0-rmse:0.19673
# [421]	validation_0-rmse:0.19672
# [422]	validation_0-rmse:0.19669
# [423]	validation_0-rmse:0.19672
# [424]	validation_0-rmse:0.19669
# [425]	validation_0-rmse:0.19678
# [426]	validation_0-rmse:0.19684
# [427]	validation_0-rmse:0.19680
# [428]	validation_0-rmse:0.19677
# [429]	validation_0-rmse:0.19684
# [430]	validation_0-rmse:0.19683
# [431]	validation_0-rmse:0.19686
# [432]	validation_0-rmse:0.19690
# [433]	validation_0-rmse:0.19685
# [434]	validation_0-rmse:0.19692
# [435]	validation_0-rmse:0.19693
# [436]	validation_0-rmse:0.19693
# [437]	validation_0-rmse:0.19694
# [438]	validation_0-rmse:0.19690
# [439]	validation_0-rmse:0.19692
# [440]	validation_0-rmse:0.19692
# [441]	validation_0-rmse:0.19693
# [442]	validation_0-rmse:0.19697
# [443]	validation_0-rmse:0.19690
# [444]	validation_0-rmse:0.19687
# [445]	validation_0-rmse:0.19686
# [446]	validation_0-rmse:0.19691
# [447]	validation_0-rmse:0.19690
# [448]	validation_0-rmse:0.19690
# [449]	validation_0-rmse:0.19693
# [450]	validation_0-rmse:0.19692
# [451]	validation_0-rmse:0.19693
# [452]	validation_0-rmse:0.19697
# [453]	validation_0-rmse:0.19695
# [454]	validation_0-rmse:0.19705
# [455]	validation_0-rmse:0.19704
# [456]	validation_0-rmse:0.19701
# [457]	validation_0-rmse:0.19698
# [458]	validation_0-rmse:0.19698
# [459]	validation_0-rmse:0.19696
# [460]	validation_0-rmse:0.19695
# [461]	validation_0-rmse:0.19694
# [462]	validation_0-rmse:0.19694
# [463]	validation_0-rmse:0.19695
# [464]	validation_0-rmse:0.19697
# [465]	validation_0-rmse:0.19697
# [466]	validation_0-rmse:0.19697
# [467]	validation_0-rmse:0.19695
# [468]	validation_0-rmse:0.19695
# [469]	validation_0-rmse:0.19698
# [470]	validation_0-rmse:0.19704
# [471]	validation_0-rmse:0.19700
# [472]	validation_0-rmse:0.19698
# [473]	validation_0-rmse:0.19694
# [474]	validation_0-rmse:0.19694
# [475]	validation_0-rmse:0.19696
# [476]	validation_0-rmse:0.19700
# [477]	validation_0-rmse:0.19700
# [478]	validation_0-rmse:0.19704
# [479]	validation_0-rmse:0.19703
# [480]	validation_0-rmse:0.19708
# [481]	validation_0-rmse:0.19708
# [482]	validation_0-rmse:0.19709
# [483]	validation_0-rmse:0.19710
# [484]	validation_0-rmse:0.19711
# [485]	validation_0-rmse:0.19712
# [486]	validation_0-rmse:0.19713
# [487]	validation_0-rmse:0.19716
# [488]	validation_0-rmse:0.19711
# [489]	validation_0-rmse:0.19708
# [490]	validation_0-rmse:0.19706
# [491]	validation_0-rmse:0.19709
# [492]	validation_0-rmse:0.19709
# [493]	validation_0-rmse:0.19710
# [494]	validation_0-rmse:0.19708
# [495]	validation_0-rmse:0.19709
# [496]	validation_0-rmse:0.19711
# [497]	validation_0-rmse:0.19709
# [498]	validation_0-rmse:0.19719
# [499]	validation_0-rmse:0.19721
# [500]	validation_0-rmse:0.19718
# [501]	validation_0-rmse:0.19716
# [502]	validation_0-rmse:0.19716
# [503]	validation_0-rmse:0.19721
# [504]	validation_0-rmse:0.19720
# [505]	validation_0-rmse:0.19721
# [506]	validation_0-rmse:0.19719
# [507]	validation_0-rmse:0.19720
# [508]	validation_0-rmse:0.19718
# [509]	validation_0-rmse:0.19714
# [510]	validation_0-rmse:0.19719
# [511]	validation_0-rmse:0.19720
# [512]	validation_0-rmse:0.19721
# [513]	validation_0-rmse:0.19726
# [514]	validation_0-rmse:0.19726
# [515]	validation_0-rmse:0.19726
# [516]	validation_0-rmse:0.19725
# [517]	validation_0-rmse:0.19726
# [518]	validation_0-rmse:0.19727
# [519]	validation_0-rmse:0.19725
# [520]	validation_0-rmse:0.19725
# [521]	validation_0-rmse:0.19726
# [522]	validation_0-rmse:0.19720
# [523]	validation_0-rmse:0.19720
# [524]	validation_0-rmse:0.19718
# [525]	validation_0-rmse:0.19717
# [526]	validation_0-rmse:0.19719
# [527]	validation_0-rmse:0.19720
# [528]	validation_0-rmse:0.19723
# [529]	validation_0-rmse:0.19724
# [530]	validation_0-rmse:0.19724
# [531]	validation_0-rmse:0.19726
# [532]	validation_0-rmse:0.19726
# [533]	validation_0-rmse:0.19725
# [534]	validation_0-rmse:0.19727
# [535]	validation_0-rmse:0.19730
# [536]	validation_0-rmse:0.19732
# [537]	validation_0-rmse:0.19730
# [538]	validation_0-rmse:0.19733
# [539]	validation_0-rmse:0.19732
# [540]	validation_0-rmse:0.19733
# [541]	validation_0-rmse:0.19733
# [542]	validation_0-rmse:0.19732
# [543]	validation_0-rmse:0.19733
# [544]	validation_0-rmse:0.19734
# [545]	validation_0-rmse:0.19734
# [546]	validation_0-rmse:0.19732
# [547]	validation_0-rmse:0.19732
# [548]	validation_0-rmse:0.19731
# [549]	validation_0-rmse:0.19730
# [550]	validation_0-rmse:0.19731
# [551]	validation_0-rmse:0.19731
# [552]	validation_0-rmse:0.19730
# [553]	validation_0-rmse:0.19729
# [554]	validation_0-rmse:0.19730
# [555]	validation_0-rmse:0.19731
# [556]	validation_0-rmse:0.19732
# [557]	validation_0-rmse:0.19730
# [558]	validation_0-rmse:0.19729
# [559]	validation_0-rmse:0.19731
# [560]	validation_0-rmse:0.19735
# [561]	validation_0-rmse:0.19737
# [562]	validation_0-rmse:0.19736
# [563]	validation_0-rmse:0.19736
# [564]	validation_0-rmse:0.19736
# [565]	validation_0-rmse:0.19735
# [566]	validation_0-rmse:0.19729
# [567]	validation_0-rmse:0.19729
# [568]	validation_0-rmse:0.19727
# [569]	validation_0-rmse:0.19727
# [570]	validation_0-rmse:0.19726
# [571]	validation_0-rmse:0.19726
# [572]	validation_0-rmse:0.19726
# [573]	validation_0-rmse:0.19726
# [574]	validation_0-rmse:0.19725
# [575]	validation_0-rmse:0.19725
# [576]	validation_0-rmse:0.19725
# [577]	validation_0-rmse:0.19723
# [578]	validation_0-rmse:0.19721
# [579]	validation_0-rmse:0.19723
# [580]	validation_0-rmse:0.19724
# [581]	validation_0-rmse:0.19724
# [582]	validation_0-rmse:0.19723
# [583]	validation_0-rmse:0.19724
# [584]	validation_0-rmse:0.19723
# [585]	validation_0-rmse:0.19720
# [586]	validation_0-rmse:0.19721
# [587]	validation_0-rmse:0.19721
# [588]	validation_0-rmse:0.19722
# [589]	validation_0-rmse:0.19722
# [590]	validation_0-rmse:0.19722
# [591]	validation_0-rmse:0.19720
# [592]	validation_0-rmse:0.19720
# [593]	validation_0-rmse:0.19719
# [594]	validation_0-rmse:0.19718
# [595]	validation_0-rmse:0.19720
# [596]	validation_0-rmse:0.19724
# [597]	validation_0-rmse:0.19721
# [598]	validation_0-rmse:0.19720
# [599]	validation_0-rmse:0.19722
# [600]	validation_0-rmse:0.19721
# [601]	validation_0-rmse:0.19724
# [602]	validation_0-rmse:0.19723
# [603]	validation_0-rmse:0.19723
# [604]	validation_0-rmse:0.19725
# [605]	validation_0-rmse:0.19725
# [606]	validation_0-rmse:0.19725
# [607]	validation_0-rmse:0.19724
# [608]	validation_0-rmse:0.19722
# [609]	validation_0-rmse:0.19721
# [610]	validation_0-rmse:0.19720
# [611]	validation_0-rmse:0.19719
# [612]	validation_0-rmse:0.19719
# [613]	validation_0-rmse:0.19719
# [614]	validation_0-rmse:0.19718
# [615]	validation_0-rmse:0.19718
# [616]	validation_0-rmse:0.19718
# [617]	validation_0-rmse:0.19717
# [618]	validation_0-rmse:0.19718
# [619]	validation_0-rmse:0.19719
# [620]	validation_0-rmse:0.19721
# [621]	validation_0-rmse:0.19723
# [622]	validation_0-rmse:0.19724
# [623]	validation_0-rmse:0.19724
# [624]	validation_0-rmse:0.19724
# [625]	validation_0-rmse:0.19722
# [626]	validation_0-rmse:0.19725
# [627]	validation_0-rmse:0.19727
# [628]	validation_0-rmse:0.19726
# [629]	validation_0-rmse:0.19727
# [630]	validation_0-rmse:0.19729
# [631]	validation_0-rmse:0.19728
# [632]	validation_0-rmse:0.19728
# [633]	validation_0-rmse:0.19729
# [634]	validation_0-rmse:0.19728
# [635]	validation_0-rmse:0.19728
# [636]	validation_0-rmse:0.19728
# [637]	validation_0-rmse:0.19728
# [638]	validation_0-rmse:0.19728
# [639]	validation_0-rmse:0.19727
# [640]	validation_0-rmse:0.19726
# [641]	validation_0-rmse:0.19729
# [642]	validation_0-rmse:0.19728
# [643]	validation_0-rmse:0.19728
# [644]	validation_0-rmse:0.19728
# [645]	validation_0-rmse:0.19728
# [646]	validation_0-rmse:0.19729
# [647]	validation_0-rmse:0.19730
# [648]	validation_0-rmse:0.19730
# [649]	validation_0-rmse:0.19730
# [650]	validation_0-rmse:0.19731
# [651]	validation_0-rmse:0.19730
# [652]	validation_0-rmse:0.19730
# [653]	validation_0-rmse:0.19730
# [654]	validation_0-rmse:0.19730
# [655]	validation_0-rmse:0.19731
# [656]	validation_0-rmse:0.19731
# [657]	validation_0-rmse:0.19731
# [658]	validation_0-rmse:0.19731
# [659]	validation_0-rmse:0.19730
# [660]	validation_0-rmse:0.19730
# [661]	validation_0-rmse:0.19730
# [662]	validation_0-rmse:0.19731
# [663]	validation_0-rmse:0.19731
# [664]	validation_0-rmse:0.19728
# [665]	validation_0-rmse:0.19728
# [666]	validation_0-rmse:0.19727
# [667]	validation_0-rmse:0.19727
# [668]	validation_0-rmse:0.19726
# [669]	validation_0-rmse:0.19726
# [670]	validation_0-rmse:0.19726
# [671]	validation_0-rmse:0.19726
# [672]	validation_0-rmse:0.19725
# [673]	validation_0-rmse:0.19724
# [674]	validation_0-rmse:0.19725
# [675]	validation_0-rmse:0.19724
# [676]	validation_0-rmse:0.19725
# [677]	validation_0-rmse:0.19725
# [678]	validation_0-rmse:0.19725
# [679]	validation_0-rmse:0.19724
# [680]	validation_0-rmse:0.19723
# [681]	validation_0-rmse:0.19724
# [682]	validation_0-rmse:0.19725
# [683]	validation_0-rmse:0.19726
# [684]	validation_0-rmse:0.19726
# [685]	validation_0-rmse:0.19726
# [686]	validation_0-rmse:0.19726
# [687]	validation_0-rmse:0.19725
# [688]	validation_0-rmse:0.19726
# [689]	validation_0-rmse:0.19725
# [690]	validation_0-rmse:0.19723
# [691]	validation_0-rmse:0.19723
# [692]	validation_0-rmse:0.19724
# [693]	validation_0-rmse:0.19724
# [694]	validation_0-rmse:0.19726
# [695]	validation_0-rmse:0.19726
# [696]	validation_0-rmse:0.19726
# [697]	validation_0-rmse:0.19726
# [698]	validation_0-rmse:0.19726
# [699]	validation_0-rmse:0.19727
# [700]	validation_0-rmse:0.19726
# [701]	validation_0-rmse:0.19726
# [702]	validation_0-rmse:0.19727
# [703]	validation_0-rmse:0.19726
# [704]	validation_0-rmse:0.19726
# [705]	validation_0-rmse:0.19726
# [706]	validation_0-rmse:0.19726
# [707]	validation_0-rmse:0.19726
# [708]	validation_0-rmse:0.19726
# [709]	validation_0-rmse:0.19726
# [710]	validation_0-rmse:0.19726
# [711]	validation_0-rmse:0.19726
# [712]	validation_0-rmse:0.19726
# [713]	validation_0-rmse:0.19726
# [714]	validation_0-rmse:0.19725
# [715]	validation_0-rmse:0.19725
# [716]	validation_0-rmse:0.19724
# [717]	validation_0-rmse:0.19724
# [718]	validation_0-rmse:0.19725
# [719]	validation_0-rmse:0.19725
# [720]	validation_0-rmse:0.19726
# [721]	validation_0-rmse:0.19726
# [722]	validation_0-rmse:0.19726
# [723]	validation_0-rmse:0.19727
# [724]	validation_0-rmse:0.19727
# [725]	validation_0-rmse:0.19727
# [726]	validation_0-rmse:0.19728
# [727]	validation_0-rmse:0.19728
# [728]	validation_0-rmse:0.19728
# [729]	validation_0-rmse:0.19728
# [730]	validation_0-rmse:0.19728
# [731]	validation_0-rmse:0.19727
# [732]	validation_0-rmse:0.19727
# [733]	validation_0-rmse:0.19726
# [734]	validation_0-rmse:0.19726
# [735]	validation_0-rmse:0.19725
# [736]	validation_0-rmse:0.19724
# [737]	validation_0-rmse:0.19725
# [738]	validation_0-rmse:0.19725
# [739]	validation_0-rmse:0.19726
# [740]	validation_0-rmse:0.19726
# [741]	validation_0-rmse:0.19726
# [742]	validation_0-rmse:0.19725
# [743]	validation_0-rmse:0.19725
# [744]	validation_0-rmse:0.19725
# [745]	validation_0-rmse:0.19725
# [746]	validation_0-rmse:0.19725
# [747]	validation_0-rmse:0.19725
# [748]	validation_0-rmse:0.19726
# [749]	validation_0-rmse:0.19725
# [750]	validation_0-rmse:0.19725
# [751]	validation_0-rmse:0.19725
# [752]	validation_0-rmse:0.19725
# [753]	validation_0-rmse:0.19725
# [754]	validation_0-rmse:0.19725
# [755]	validation_0-rmse:0.19725
# [756]	validation_0-rmse:0.19725
# [757]	validation_0-rmse:0.19726
# [758]	validation_0-rmse:0.19726
# [759]	validation_0-rmse:0.19727
# [760]	validation_0-rmse:0.19727
# [761]	validation_0-rmse:0.19727
# [762]	validation_0-rmse:0.19728
# [763]	validation_0-rmse:0.19728
# [764]	validation_0-rmse:0.19728
# [765]	validation_0-rmse:0.19729
# [766]	validation_0-rmse:0.19729
# [767]	validation_0-rmse:0.19727
# [768]	validation_0-rmse:0.19727
# [769]	validation_0-rmse:0.19726
# [770]	validation_0-rmse:0.19727
# [771]	validation_0-rmse:0.19726
# [772]	validation_0-rmse:0.19727
# [773]	validation_0-rmse:0.19727
# [774]	validation_0-rmse:0.19727
# [775]	validation_0-rmse:0.19727
# [776]	validation_0-rmse:0.19727
# [777]	validation_0-rmse:0.19727
# [778]	validation_0-rmse:0.19727
# [779]	validation_0-rmse:0.19727
# [780]	validation_0-rmse:0.19727
# [781]	validation_0-rmse:0.19727
# [782]	validation_0-rmse:0.19726
# [783]	validation_0-rmse:0.19727
# [784]	validation_0-rmse:0.19728
# [785]	validation_0-rmse:0.19728
# [786]	validation_0-rmse:0.19728
# [787]	validation_0-rmse:0.19728
# [788]	validation_0-rmse:0.19729
# [789]	validation_0-rmse:0.19729
# [790]	validation_0-rmse:0.19729
# [791]	validation_0-rmse:0.19729
# [792]	validation_0-rmse:0.19729
# [793]	validation_0-rmse:0.19729
# [794]	validation_0-rmse:0.19730
# [795]	validation_0-rmse:0.19730
# [796]	validation_0-rmse:0.19730
# [797]	validation_0-rmse:0.19730
# [798]	validation_0-rmse:0.19730
# [799]	validation_0-rmse:0.19730
# [800]	validation_0-rmse:0.19730
# [801]	validation_0-rmse:0.19731
# [802]	validation_0-rmse:0.19731
# [803]	validation_0-rmse:0.19731
# [804]	validation_0-rmse:0.19731
# [805]	validation_0-rmse:0.19731
# [806]	validation_0-rmse:0.19730
# [807]	validation_0-rmse:0.19730
# [808]	validation_0-rmse:0.19730
# [809]	validation_0-rmse:0.19730
# [810]	validation_0-rmse:0.19730
# [811]	validation_0-rmse:0.19730
# [812]	validation_0-rmse:0.19730
# [813]	validation_0-rmse:0.19730
# [814]	validation_0-rmse:0.19730
# [815]	validation_0-rmse:0.19730
# [816]	validation_0-rmse:0.19731
# [817]	validation_0-rmse:0.19731
# [818]	validation_0-rmse:0.19731
# [819]	validation_0-rmse:0.19731
# [820]	validation_0-rmse:0.19731
# [821]	validation_0-rmse:0.19730
# [822]	validation_0-rmse:0.19731
# [823]	validation_0-rmse:0.19730
# [824]	validation_0-rmse:0.19731
# [825]	validation_0-rmse:0.19730
# [826]	validation_0-rmse:0.19731
# [827]	validation_0-rmse:0.19731
# [828]	validation_0-rmse:0.19731
# [829]	validation_0-rmse:0.19731
# [830]	validation_0-rmse:0.19731
# [831]	validation_0-rmse:0.19732
# [832]	validation_0-rmse:0.19731
# [833]	validation_0-rmse:0.19731
# [834]	validation_0-rmse:0.19731
# [835]	validation_0-rmse:0.19732
# [836]	validation_0-rmse:0.19732
# [837]	validation_0-rmse:0.19732
# [838]	validation_0-rmse:0.19732
# [839]	validation_0-rmse:0.19732
# [840]	validation_0-rmse:0.19732
# [841]	validation_0-rmse:0.19732
# [842]	validation_0-rmse:0.19732
# [843]	validation_0-rmse:0.19732
# [844]	validation_0-rmse:0.19732
# [845]	validation_0-rmse:0.19732
# [846]	validation_0-rmse:0.19731
# [847]	validation_0-rmse:0.19731
# [848]	validation_0-rmse:0.19731
# [849]	validation_0-rmse:0.19732
# [850]	validation_0-rmse:0.19732
# [851]	validation_0-rmse:0.19732
# [852]	validation_0-rmse:0.19732
# [853]	validation_0-rmse:0.19732
# [854]	validation_0-rmse:0.19732
# [855]	validation_0-rmse:0.19732
# [856]	validation_0-rmse:0.19732
# [857]	validation_0-rmse:0.19732
# [858]	validation_0-rmse:0.19732
# [859]	validation_0-rmse:0.19732
# [860]	validation_0-rmse:0.19733
# [861]	validation_0-rmse:0.19733
# [862]	validation_0-rmse:0.19734
# [863]	validation_0-rmse:0.19734
# [864]	validation_0-rmse:0.19734
# [865]	validation_0-rmse:0.19734
# [866]	validation_0-rmse:0.19734
# [867]	validation_0-rmse:0.19734
# [868]	validation_0-rmse:0.19735
# [869]	validation_0-rmse:0.19735
# [870]	validation_0-rmse:0.19735
# [871]	validation_0-rmse:0.19735
# [872]	validation_0-rmse:0.19734
# [873]	validation_0-rmse:0.19735
# [874]	validation_0-rmse:0.19735
# [875]	validation_0-rmse:0.19736
# [876]	validation_0-rmse:0.19736
# [877]	validation_0-rmse:0.19736
# [878]	validation_0-rmse:0.19736
# [879]	validation_0-rmse:0.19736
# [880]	validation_0-rmse:0.19736
# [881]	validation_0-rmse:0.19736
# [882]	validation_0-rmse:0.19736
# [883]	validation_0-rmse:0.19735
# [884]	validation_0-rmse:0.19735
# [885]	validation_0-rmse:0.19735
# [886]	validation_0-rmse:0.19735
# [887]	validation_0-rmse:0.19735
# [888]	validation_0-rmse:0.19735
# [889]	validation_0-rmse:0.19735
# [890]	validation_0-rmse:0.19735
# [891]	validation_0-rmse:0.19735
# [892]	validation_0-rmse:0.19735
# [893]	validation_0-rmse:0.19735
# [894]	validation_0-rmse:0.19735
# [895]	validation_0-rmse:0.19735
# [896]	validation_0-rmse:0.19735
# [897]	validation_0-rmse:0.19735
# [898]	validation_0-rmse:0.19736
# [899]	validation_0-rmse:0.19735
# [900]	validation_0-rmse:0.19735
# [901]	validation_0-rmse:0.19735
# [902]	validation_0-rmse:0.19735
# [903]	validation_0-rmse:0.19735
# [904]	validation_0-rmse:0.19735
# [905]	validation_0-rmse:0.19735
# [906]	validation_0-rmse:0.19735
# [907]	validation_0-rmse:0.19736
# [908]	validation_0-rmse:0.19736
# [909]	validation_0-rmse:0.19736
# [910]	validation_0-rmse:0.19737
# [911]	validation_0-rmse:0.19737
# [912]	validation_0-rmse:0.19737
# [913]	validation_0-rmse:0.19737
# [914]	validation_0-rmse:0.19737
# [915]	validation_0-rmse:0.19737
# [916]	validation_0-rmse:0.19737
# [917]	validation_0-rmse:0.19738
# [918]	validation_0-rmse:0.19737
# [919]	validation_0-rmse:0.19738
# [920]	validation_0-rmse:0.19737
# [921]	validation_0-rmse:0.19738
# [922]	validation_0-rmse:0.19737
# [923]	validation_0-rmse:0.19738
# [924]	validation_0-rmse:0.19738
# [925]	validation_0-rmse:0.19738
# [926]	validation_0-rmse:0.19738
# [927]	validation_0-rmse:0.19738
# [928]	validation_0-rmse:0.19738
# [929]	validation_0-rmse:0.19738
# [930]	validation_0-rmse:0.19738
# [931]	validation_0-rmse:0.19738
# [932]	validation_0-rmse:0.19738
# [933]	validation_0-rmse:0.19738
# [934]	validation_0-rmse:0.19738
# [935]	validation_0-rmse:0.19738
# [936]	validation_0-rmse:0.19739
# [937]	validation_0-rmse:0.19739
# [938]	validation_0-rmse:0.19739
# [939]	validation_0-rmse:0.19739
# [940]	validation_0-rmse:0.19739
# [941]	validation_0-rmse:0.19739
# [942]	validation_0-rmse:0.19739
# [943]	validation_0-rmse:0.19739
# [944]	validation_0-rmse:0.19739
# [945]	validation_0-rmse:0.19740
# [946]	validation_0-rmse:0.19739
# [947]	validation_0-rmse:0.19739
# [948]	validation_0-rmse:0.19739
# [949]	validation_0-rmse:0.19739
# [950]	validation_0-rmse:0.19739
# [951]	validation_0-rmse:0.19739
# [952]	validation_0-rmse:0.19739
# [953]	validation_0-rmse:0.19739
# [954]	validation_0-rmse:0.19740
# [955]	validation_0-rmse:0.19740
# [956]	validation_0-rmse:0.19739
# [957]	validation_0-rmse:0.19739
# [958]	validation_0-rmse:0.19739
# [959]	validation_0-rmse:0.19739
# [960]	validation_0-rmse:0.19739
# [961]	validation_0-rmse:0.19739
# [962]	validation_0-rmse:0.19739
# [963]	validation_0-rmse:0.19739
# [964]	validation_0-rmse:0.19739
# [965]	validation_0-rmse:0.19739
# [966]	validation_0-rmse:0.19739
# [967]	validation_0-rmse:0.19739
# [968]	validation_0-rmse:0.19739
# [969]	validation_0-rmse:0.19739
# [970]	validation_0-rmse:0.19739
# [971]	validation_0-rmse:0.19739
# [972]	validation_0-rmse:0.19739
# [973]	validation_0-rmse:0.19739
# [974]	validation_0-rmse:0.19739
# [975]	validation_0-rmse:0.19739
# [976]	validation_0-rmse:0.19739
# [977]	validation_0-rmse:0.19739
# [978]	validation_0-rmse:0.19739
# [979]	validation_0-rmse:0.19739
# [980]	validation_0-rmse:0.19739
# [981]	validation_0-rmse:0.19739
# [982]	validation_0-rmse:0.19739
# [983]	validation_0-rmse:0.19739
# [984]	validation_0-rmse:0.19739
# [985]	validation_0-rmse:0.19739
# [986]	validation_0-rmse:0.19739
# [987]	validation_0-rmse:0.19739
# [988]	validation_0-rmse:0.19739
# [989]	validation_0-rmse:0.19739
# [990]	validation_0-rmse:0.19739
# [991]	validation_0-rmse:0.19739
# [992]	validation_0-rmse:0.19740
# [993]	validation_0-rmse:0.19740
# [994]	validation_0-rmse:0.19740
# [995]	validation_0-rmse:0.19739
# [996]	validation_0-rmse:0.19739
# [997]	validation_0-rmse:0.19739
# [998]	validation_0-rmse:0.19739
# [999]	validation_0-rmse:0.19739
# 0.2044667820402567 0.32418984
# [0]	validation_0-rmse:0.39953
# [1]	validation_0-rmse:0.37314
# [2]	validation_0-rmse:0.35646
# [3]	validation_0-rmse:0.34166
# [4]	validation_0-rmse:0.32740
# [5]	validation_0-rmse:0.31434
# [6]	validation_0-rmse:0.30382
# [7]	validation_0-rmse:0.29256
# [8]	validation_0-rmse:0.28749
# [9]	validation_0-rmse:0.28019
# [10]	validation_0-rmse:0.27496
# [11]	validation_0-rmse:0.26767
# [12]	validation_0-rmse:0.26180
# [13]	validation_0-rmse:0.25746
# [14]	validation_0-rmse:0.25536
# [15]	validation_0-rmse:0.25545
# [16]	validation_0-rmse:0.25360
# [17]	validation_0-rmse:0.25358
# [18]	validation_0-rmse:0.25342
# [19]	validation_0-rmse:0.25100
# [20]	validation_0-rmse:0.25053
# [21]	validation_0-rmse:0.24924
# [22]	validation_0-rmse:0.24834
# [23]	validation_0-rmse:0.24725
# [24]	validation_0-rmse:0.24764
# [25]	validation_0-rmse:0.24674
# [26]	validation_0-rmse:0.24697
# [27]	validation_0-rmse:0.24677
# [28]	validation_0-rmse:0.24799
# [29]	validation_0-rmse:0.24863
# [30]	validation_0-rmse:0.24841
# [31]	validation_0-rmse:0.24801
# [32]	validation_0-rmse:0.24798
# [33]	validation_0-rmse:0.24870
# [34]	validation_0-rmse:0.24859
# [35]	validation_0-rmse:0.24909
# [36]	validation_0-rmse:0.24887
# [37]	validation_0-rmse:0.24873
# [38]	validation_0-rmse:0.24876
# [39]	validation_0-rmse:0.24953
# [40]	validation_0-rmse:0.24964
# [41]	validation_0-rmse:0.25023
# [42]	validation_0-rmse:0.25032
# [43]	validation_0-rmse:0.24995
# [44]	validation_0-rmse:0.24929
# [45]	validation_0-rmse:0.24875
# [46]	validation_0-rmse:0.24922
# [47]	validation_0-rmse:0.24869
# [48]	validation_0-rmse:0.24909
# [49]	validation_0-rmse:0.24873
# [50]	validation_0-rmse:0.24880
# [51]	validation_0-rmse:0.24883
# [52]	validation_0-rmse:0.24925
# [53]	validation_0-rmse:0.24935
# [54]	validation_0-rmse:0.24966
# [55]	validation_0-rmse:0.24909
# [56]	validation_0-rmse:0.24839
# [57]	validation_0-rmse:0.24824
# [58]	validation_0-rmse:0.24872
# [59]	validation_0-rmse:0.24907
# [60]	validation_0-rmse:0.24919
# [61]	validation_0-rmse:0.24990
# [62]	validation_0-rmse:0.24995
# [63]	validation_0-rmse:0.25074
# [64]	validation_0-rmse:0.25063
# [65]	validation_0-rmse:0.25105
# [66]	validation_0-rmse:0.25094
# [67]	validation_0-rmse:0.25046
# [68]	validation_0-rmse:0.24976
# [69]	validation_0-rmse:0.25033
# [70]	validation_0-rmse:0.25047
# [71]	validation_0-rmse:0.25043
# [72]	validation_0-rmse:0.25037
# [73]	validation_0-rmse:0.24935
# [74]	validation_0-rmse:0.24979
# [75]	validation_0-rmse:0.24986
# [76]	validation_0-rmse:0.24960
# [77]	validation_0-rmse:0.24945
# [78]	validation_0-rmse:0.24973
# [79]	validation_0-rmse:0.25007
# [80]	validation_0-rmse:0.25006
# [81]	validation_0-rmse:0.24998
# [82]	validation_0-rmse:0.25018
# [83]	validation_0-rmse:0.25017
# [84]	validation_0-rmse:0.25006
# [85]	validation_0-rmse:0.25100
# [86]	validation_0-rmse:0.25203
# [87]	validation_0-rmse:0.25213
# [88]	validation_0-rmse:0.25179
# [89]	validation_0-rmse:0.25179
# [90]	validation_0-rmse:0.25175
# [91]	validation_0-rmse:0.25177
# [92]	validation_0-rmse:0.25152
# [93]	validation_0-rmse:0.25142
# [94]	validation_0-rmse:0.25128
# [95]	validation_0-rmse:0.25127
# [96]	validation_0-rmse:0.25174
# [97]	validation_0-rmse:0.25203
# [98]	validation_0-rmse:0.25188
# [99]	validation_0-rmse:0.25220
# [100]	validation_0-rmse:0.25246
# [101]	validation_0-rmse:0.25220
# [102]	validation_0-rmse:0.25198
# [103]	validation_0-rmse:0.25142
# [104]	validation_0-rmse:0.25123
# [105]	validation_0-rmse:0.25118
# [106]	validation_0-rmse:0.25074
# [107]	validation_0-rmse:0.25036
# [108]	validation_0-rmse:0.25025
# [109]	validation_0-rmse:0.25024
# [110]	validation_0-rmse:0.25058
# [111]	validation_0-rmse:0.25073
# [112]	validation_0-rmse:0.25036
# [113]	validation_0-rmse:0.24962
# [114]	validation_0-rmse:0.24960
# [115]	validation_0-rmse:0.24971
# [116]	validation_0-rmse:0.24965
# [117]	validation_0-rmse:0.24935
# [118]	validation_0-rmse:0.24986
# [119]	validation_0-rmse:0.25051
# [120]	validation_0-rmse:0.25049
# [121]	validation_0-rmse:0.25062
# [122]	validation_0-rmse:0.25046
# [123]	validation_0-rmse:0.25051
# [124]	validation_0-rmse:0.25075
# [125]	validation_0-rmse:0.25078
# [126]	validation_0-rmse:0.25077
# [127]	validation_0-rmse:0.25063
# [128]	validation_0-rmse:0.25069
# [129]	validation_0-rmse:0.25085
# [130]	validation_0-rmse:0.25044
# [131]	validation_0-rmse:0.25057
# [132]	validation_0-rmse:0.25047
# [133]	validation_0-rmse:0.25017
# [134]	validation_0-rmse:0.25004
# [135]	validation_0-rmse:0.24988
# [136]	validation_0-rmse:0.24991
# [137]	validation_0-rmse:0.25005
# [138]	validation_0-rmse:0.25012
# [139]	validation_0-rmse:0.25045
# [140]	validation_0-rmse:0.25031
# [141]	validation_0-rmse:0.25011
# [142]	validation_0-rmse:0.25020
# [143]	validation_0-rmse:0.25014
# [144]	validation_0-rmse:0.25019
# [145]	validation_0-rmse:0.25021
# [146]	validation_0-rmse:0.25045
# [147]	validation_0-rmse:0.25054
# [148]	validation_0-rmse:0.25035
# [149]	validation_0-rmse:0.25072
# [150]	validation_0-rmse:0.25070
# [151]	validation_0-rmse:0.25032
# [152]	validation_0-rmse:0.25004
# [153]	validation_0-rmse:0.25009
# [154]	validation_0-rmse:0.25018
# [155]	validation_0-rmse:0.25022
# [156]	validation_0-rmse:0.25059
# [157]	validation_0-rmse:0.25058
# [158]	validation_0-rmse:0.25067
# [159]	validation_0-rmse:0.25047
# [160]	validation_0-rmse:0.25059
# [161]	validation_0-rmse:0.25062
# [162]	validation_0-rmse:0.25082
# [163]	validation_0-rmse:0.25088
# [164]	validation_0-rmse:0.25093
# [165]	validation_0-rmse:0.25027
# [166]	validation_0-rmse:0.24992
# [167]	validation_0-rmse:0.24997
# [168]	validation_0-rmse:0.25023
# [169]	validation_0-rmse:0.25010
# [170]	validation_0-rmse:0.24992
# [171]	validation_0-rmse:0.24959
# [172]	validation_0-rmse:0.24979
# [173]	validation_0-rmse:0.24949
# [174]	validation_0-rmse:0.24931
# [175]	validation_0-rmse:0.24940
# [176]	validation_0-rmse:0.24929
# [177]	validation_0-rmse:0.24930
# [178]	validation_0-rmse:0.24984
# [179]	validation_0-rmse:0.24993
# [180]	validation_0-rmse:0.24991
# [181]	validation_0-rmse:0.25008
# [182]	validation_0-rmse:0.24974
# [183]	validation_0-rmse:0.24971
# [184]	validation_0-rmse:0.24971
# [185]	validation_0-rmse:0.24976
# [186]	validation_0-rmse:0.24987
# [187]	validation_0-rmse:0.25009
# [188]	validation_0-rmse:0.24998
# [189]	validation_0-rmse:0.25000
# [190]	validation_0-rmse:0.25013
# [191]	validation_0-rmse:0.25022
# [192]	validation_0-rmse:0.25020
# [193]	validation_0-rmse:0.25010
# [194]	validation_0-rmse:0.25019
# [195]	validation_0-rmse:0.25012
# [196]	validation_0-rmse:0.25009
# [197]	validation_0-rmse:0.25041
# [198]	validation_0-rmse:0.25056
# [199]	validation_0-rmse:0.25055
# [200]	validation_0-rmse:0.25048
# [201]	validation_0-rmse:0.25039
# [202]	validation_0-rmse:0.25035
# [203]	validation_0-rmse:0.25040
# [204]	validation_0-rmse:0.25036
# [205]	validation_0-rmse:0.25042
# [206]	validation_0-rmse:0.25018
# [207]	validation_0-rmse:0.25019
# [208]	validation_0-rmse:0.25009
# [209]	validation_0-rmse:0.25001
# [210]	validation_0-rmse:0.25018
# [211]	validation_0-rmse:0.25007
# [212]	validation_0-rmse:0.25063
# [213]	validation_0-rmse:0.25074
# [214]	validation_0-rmse:0.25067
# [215]	validation_0-rmse:0.25065
# [216]	validation_0-rmse:0.25071
# [217]	validation_0-rmse:0.25058
# [218]	validation_0-rmse:0.25068
# [219]	validation_0-rmse:0.25064
# [220]	validation_0-rmse:0.25047
# [221]	validation_0-rmse:0.25046
# [222]	validation_0-rmse:0.25044
# [223]	validation_0-rmse:0.25079
# [224]	validation_0-rmse:0.25053
# [225]	validation_0-rmse:0.25053
# [226]	validation_0-rmse:0.25065
# [227]	validation_0-rmse:0.25052
# [228]	validation_0-rmse:0.25029
# [229]	validation_0-rmse:0.25037
# [230]	validation_0-rmse:0.25055
# [231]	validation_0-rmse:0.25043
# [232]	validation_0-rmse:0.25061
# [233]	validation_0-rmse:0.25066
# [234]	validation_0-rmse:0.25063
# [235]	validation_0-rmse:0.25061
# [236]	validation_0-rmse:0.25064
# [237]	validation_0-rmse:0.25065
# [238]	validation_0-rmse:0.25086
# [239]	validation_0-rmse:0.25080
# [240]	validation_0-rmse:0.25080
# [241]	validation_0-rmse:0.25045
# [242]	validation_0-rmse:0.25052
# [243]	validation_0-rmse:0.25055
# [244]	validation_0-rmse:0.25043
# [245]	validation_0-rmse:0.25039
# [246]	validation_0-rmse:0.25041
# [247]	validation_0-rmse:0.25029
# [248]	validation_0-rmse:0.25033
# [249]	validation_0-rmse:0.25041
# [250]	validation_0-rmse:0.25029
# [251]	validation_0-rmse:0.25017
# [252]	validation_0-rmse:0.25030
# [253]	validation_0-rmse:0.25019
# [254]	validation_0-rmse:0.25004
# [255]	validation_0-rmse:0.24999
# [256]	validation_0-rmse:0.25002
# [257]	validation_0-rmse:0.24980
# [258]	validation_0-rmse:0.24967
# [259]	validation_0-rmse:0.24944
# [260]	validation_0-rmse:0.24943
# [261]	validation_0-rmse:0.24940
# [262]	validation_0-rmse:0.24957
# [263]	validation_0-rmse:0.24957
# [264]	validation_0-rmse:0.24963
# [265]	validation_0-rmse:0.24971
# [266]	validation_0-rmse:0.24984
# [267]	validation_0-rmse:0.24989
# [268]	validation_0-rmse:0.24965
# [269]	validation_0-rmse:0.24970
# [270]	validation_0-rmse:0.24916
# [271]	validation_0-rmse:0.24912
# [272]	validation_0-rmse:0.24897
# [273]	validation_0-rmse:0.24886
# [274]	validation_0-rmse:0.24898
# [275]	validation_0-rmse:0.24896
# [276]	validation_0-rmse:0.24889
# [277]	validation_0-rmse:0.24887
# [278]	validation_0-rmse:0.24884
# [279]	validation_0-rmse:0.24881
# [280]	validation_0-rmse:0.24876
# [281]	validation_0-rmse:0.24880
# [282]	validation_0-rmse:0.24883
# [283]	validation_0-rmse:0.24876
# [284]	validation_0-rmse:0.24866
# [285]	validation_0-rmse:0.24858
# [286]	validation_0-rmse:0.24878
# [287]	validation_0-rmse:0.24881
# [288]	validation_0-rmse:0.24862
# [289]	validation_0-rmse:0.24857
# [290]	validation_0-rmse:0.24835
# [291]	validation_0-rmse:0.24832
# [292]	validation_0-rmse:0.24827
# [293]	validation_0-rmse:0.24822
# [294]	validation_0-rmse:0.24824
# [295]	validation_0-rmse:0.24821
# [296]	validation_0-rmse:0.24815
# [297]	validation_0-rmse:0.24823
# [298]	validation_0-rmse:0.24829
# [299]	validation_0-rmse:0.24829
# [300]	validation_0-rmse:0.24839
# [301]	validation_0-rmse:0.24838
# [302]	validation_0-rmse:0.24834
# [303]	validation_0-rmse:0.24841
# [304]	validation_0-rmse:0.24839
# [305]	validation_0-rmse:0.24829
# [306]	validation_0-rmse:0.24839
# [307]	validation_0-rmse:0.24832
# [308]	validation_0-rmse:0.24834
# [309]	validation_0-rmse:0.24837
# [310]	validation_0-rmse:0.24836
# [311]	validation_0-rmse:0.24835
# [312]	validation_0-rmse:0.24827
# [313]	validation_0-rmse:0.24819
# [314]	validation_0-rmse:0.24819
# [315]	validation_0-rmse:0.24816
# [316]	validation_0-rmse:0.24826
# [317]	validation_0-rmse:0.24831
# [318]	validation_0-rmse:0.24835
# [319]	validation_0-rmse:0.24830
# [320]	validation_0-rmse:0.24824
# [321]	validation_0-rmse:0.24827
# [322]	validation_0-rmse:0.24815
# [323]	validation_0-rmse:0.24811
# [324]	validation_0-rmse:0.24816
# [325]	validation_0-rmse:0.24829
# [326]	validation_0-rmse:0.24830
# [327]	validation_0-rmse:0.24819
# [328]	validation_0-rmse:0.24832
# [329]	validation_0-rmse:0.24830
# [330]	validation_0-rmse:0.24827
# [331]	validation_0-rmse:0.24826
# [332]	validation_0-rmse:0.24826
# [333]	validation_0-rmse:0.24823
# [334]	validation_0-rmse:0.24828
# [335]	validation_0-rmse:0.24831
# [336]	validation_0-rmse:0.24835
# [337]	validation_0-rmse:0.24842
# [338]	validation_0-rmse:0.24849
# [339]	validation_0-rmse:0.24848
# [340]	validation_0-rmse:0.24845
# [341]	validation_0-rmse:0.24847
# [342]	validation_0-rmse:0.24851
# [343]	validation_0-rmse:0.24854
# [344]	validation_0-rmse:0.24856
# [345]	validation_0-rmse:0.24850
# [346]	validation_0-rmse:0.24850
# [347]	validation_0-rmse:0.24847
# [348]	validation_0-rmse:0.24852
# [349]	validation_0-rmse:0.24846
# [350]	validation_0-rmse:0.24839
# [351]	validation_0-rmse:0.24834
# [352]	validation_0-rmse:0.24851
# [353]	validation_0-rmse:0.24854
# [354]	validation_0-rmse:0.24855
# [355]	validation_0-rmse:0.24865
# [356]	validation_0-rmse:0.24859
# [357]	validation_0-rmse:0.24857
# [358]	validation_0-rmse:0.24857
# [359]	validation_0-rmse:0.24857
# [360]	validation_0-rmse:0.24857
# [361]	validation_0-rmse:0.24852
# [362]	validation_0-rmse:0.24852
# [363]	validation_0-rmse:0.24852
# [364]	validation_0-rmse:0.24845
# [365]	validation_0-rmse:0.24839
# [366]	validation_0-rmse:0.24839
# [367]	validation_0-rmse:0.24834
# [368]	validation_0-rmse:0.24839
# [369]	validation_0-rmse:0.24852
# [370]	validation_0-rmse:0.24849
# [371]	validation_0-rmse:0.24855
# [372]	validation_0-rmse:0.24858
# [373]	validation_0-rmse:0.24846
# [374]	validation_0-rmse:0.24854
# [375]	validation_0-rmse:0.24848
# [376]	validation_0-rmse:0.24852
# [377]	validation_0-rmse:0.24849
# [378]	validation_0-rmse:0.24858
# [379]	validation_0-rmse:0.24860
# [380]	validation_0-rmse:0.24866
# [381]	validation_0-rmse:0.24871
# [382]	validation_0-rmse:0.24873
# [383]	validation_0-rmse:0.24868
# [384]	validation_0-rmse:0.24859
# [385]	validation_0-rmse:0.24865
# [386]	validation_0-rmse:0.24868
# [387]	validation_0-rmse:0.24874
# [388]	validation_0-rmse:0.24875
# [389]	validation_0-rmse:0.24872
# [390]	validation_0-rmse:0.24879
# [391]	validation_0-rmse:0.24872
# [392]	validation_0-rmse:0.24873
# [393]	validation_0-rmse:0.24871
# [394]	validation_0-rmse:0.24873
# [395]	validation_0-rmse:0.24871
# [396]	validation_0-rmse:0.24870
# [397]	validation_0-rmse:0.24867
# [398]	validation_0-rmse:0.24868
# [399]	validation_0-rmse:0.24876
# [400]	validation_0-rmse:0.24873
# [401]	validation_0-rmse:0.24872
# [402]	validation_0-rmse:0.24867
# [403]	validation_0-rmse:0.24863
# [404]	validation_0-rmse:0.24869
# [405]	validation_0-rmse:0.24872
# [406]	validation_0-rmse:0.24871
# [407]	validation_0-rmse:0.24869
# [408]	validation_0-rmse:0.24873
# [409]	validation_0-rmse:0.24875
# [410]	validation_0-rmse:0.24879
# [411]	validation_0-rmse:0.24876
# [412]	validation_0-rmse:0.24881
# [413]	validation_0-rmse:0.24874
# [414]	validation_0-rmse:0.24866
# [415]	validation_0-rmse:0.24865
# [416]	validation_0-rmse:0.24864
# [417]	validation_0-rmse:0.24866
# [418]	validation_0-rmse:0.24865
# [419]	validation_0-rmse:0.24864
# [420]	validation_0-rmse:0.24867
# [421]	validation_0-rmse:0.24868
# [422]	validation_0-rmse:0.24880
# [423]	validation_0-rmse:0.24877
# [424]	validation_0-rmse:0.24874
# [425]	validation_0-rmse:0.24886
# [426]	validation_0-rmse:0.24888
# [427]	validation_0-rmse:0.24904
# [428]	validation_0-rmse:0.24904
# [429]	validation_0-rmse:0.24908
# [430]	validation_0-rmse:0.24910
# [431]	validation_0-rmse:0.24921
# [432]	validation_0-rmse:0.24929
# [433]	validation_0-rmse:0.24928
# [434]	validation_0-rmse:0.24934
# [435]	validation_0-rmse:0.24935
# [436]	validation_0-rmse:0.24935
# [437]	validation_0-rmse:0.24936
# [438]	validation_0-rmse:0.24934
# [439]	validation_0-rmse:0.24933
# [440]	validation_0-rmse:0.24935
# [441]	validation_0-rmse:0.24935
# [442]	validation_0-rmse:0.24936
# [443]	validation_0-rmse:0.24937
# [444]	validation_0-rmse:0.24936
# [445]	validation_0-rmse:0.24939
# [446]	validation_0-rmse:0.24937
# [447]	validation_0-rmse:0.24937
# [448]	validation_0-rmse:0.24939
# [449]	validation_0-rmse:0.24935
# [450]	validation_0-rmse:0.24939
# [451]	validation_0-rmse:0.24941
# [452]	validation_0-rmse:0.24941
# [453]	validation_0-rmse:0.24940
# [454]	validation_0-rmse:0.24945
# [455]	validation_0-rmse:0.24950
# [456]	validation_0-rmse:0.24948
# [457]	validation_0-rmse:0.24951
# [458]	validation_0-rmse:0.24952
# [459]	validation_0-rmse:0.24952
# [460]	validation_0-rmse:0.24956
# [461]	validation_0-rmse:0.24958
# [462]	validation_0-rmse:0.24957
# [463]	validation_0-rmse:0.24956
# [464]	validation_0-rmse:0.24954
# [465]	validation_0-rmse:0.24952
# [466]	validation_0-rmse:0.24956
# [467]	validation_0-rmse:0.24955
# [468]	validation_0-rmse:0.24965
# [469]	validation_0-rmse:0.24966
# [470]	validation_0-rmse:0.24965
# [471]	validation_0-rmse:0.24960
# [472]	validation_0-rmse:0.24963
# [473]	validation_0-rmse:0.24963
# [474]	validation_0-rmse:0.24963
# [475]	validation_0-rmse:0.24961
# [476]	validation_0-rmse:0.24961
# [477]	validation_0-rmse:0.24964
# [478]	validation_0-rmse:0.24966
# [479]	validation_0-rmse:0.24968
# [480]	validation_0-rmse:0.24971
# [481]	validation_0-rmse:0.24967
# [482]	validation_0-rmse:0.24965
# [483]	validation_0-rmse:0.24968
# [484]	validation_0-rmse:0.24967
# [485]	validation_0-rmse:0.24964
# [486]	validation_0-rmse:0.24964
# [487]	validation_0-rmse:0.24965
# [488]	validation_0-rmse:0.24972
# [489]	validation_0-rmse:0.24972
# [490]	validation_0-rmse:0.24977
# [491]	validation_0-rmse:0.24968
# [492]	validation_0-rmse:0.24960
# [493]	validation_0-rmse:0.24959
# [494]	validation_0-rmse:0.24959
# [495]	validation_0-rmse:0.24961
# [496]	validation_0-rmse:0.24963
# [497]	validation_0-rmse:0.24961
# [498]	validation_0-rmse:0.24959
# [499]	validation_0-rmse:0.24959
# [500]	validation_0-rmse:0.24959
# [501]	validation_0-rmse:0.24959
# [502]	validation_0-rmse:0.24960
# [503]	validation_0-rmse:0.24959
# ...
# [501]	validation_0-rmse:0.22241
# [502]	validation_0-rmse:0.22240
# [503]	validation_0-rmse:0.22242
# [504]	validation_0-rmse:0.22247
# [505]	validation_0-rmse:0.22246
# [506]	validation_0-rmse:0.22253
# [507]	validation_0-rmse:0.22248
# [508]	validation_0-rmse:0.22248
# [509]	validation_0-rmse:0.22246
# [510]	validation_0-rmse:0.22244
# [511]	validation_0-rmse:0.22245
# [512]	validation_0-rmse:0.22244
# [513]	validation_0-rmse:0.22240
# [514]	validation_0-rmse:0.22241
# [515]	validation_0-rmse:0.22247
# [516]	validation_0-rmse:0.22243
# [517]	validation_0-rmse:0.22236
# [518]	validation_0-rmse:0.22236
# [519]	validation_0-rmse:0.22240
# [520]	validation_0-rmse:0.22247
# [521]	validation_0-rmse:0.22249
# [522]	validation_0-rmse:0.22249
# [523]	validation_0-rmse:0.22248
# [524]	validation_0-rmse:0.22258
# [525]	validation_0-rmse:0.22258
# [526]	validation_0-rmse:0.22258
# [527]	validation_0-rmse:0.22256
# [528]	validation_0-rmse:0.22254
# [529]	validation_0-rmse:0.22247
# [530]	validation_0-rmse:0.22249
# [531]	validation_0-rmse:0.22249
# [532]	validation_0-rmse:0.22246
# [533]	validation_0-rmse:0.22244
# [534]	validation_0-rmse:0.22247
# [535]	validation_0-rmse:0.22242
# [536]	validation_0-rmse:0.22245
# [537]	validation_0-rmse:0.22246
# [538]	validation_0-rmse:0.22247
# [539]	validation_0-rmse:0.22247
# [540]	validation_0-rmse:0.22250
# [541]	validation_0-rmse:0.22252
# [542]	validation_0-rmse:0.22255
# [543]	validation_0-rmse:0.22254
# [544]	validation_0-rmse:0.22255
# [545]	validation_0-rmse:0.22254
# [546]	validation_0-rmse:0.22256
# [547]	validation_0-rmse:0.22258
# [548]	validation_0-rmse:0.22258
# [549]	validation_0-rmse:0.22260
# [550]	validation_0-rmse:0.22252
# [551]	validation_0-rmse:0.22249
# [552]	validation_0-rmse:0.22250
# [553]	validation_0-rmse:0.22254
# [554]	validation_0-rmse:0.22254
# [555]	validation_0-rmse:0.22253
# [556]	validation_0-rmse:0.22253
# [557]	validation_0-rmse:0.22252
# [558]	validation_0-rmse:0.22251
# [559]	validation_0-rmse:0.22251
# [560]	validation_0-rmse:0.22249
# [561]	validation_0-rmse:0.22247
# [562]	validation_0-rmse:0.22247
# [563]	validation_0-rmse:0.22248
# [564]	validation_0-rmse:0.22247
# [565]	validation_0-rmse:0.22246
# [566]	validation_0-rmse:0.22248
# [567]	validation_0-rmse:0.22238
# [568]	validation_0-rmse:0.22236
# [569]	validation_0-rmse:0.22238
# [570]	validation_0-rmse:0.22236
# [571]	validation_0-rmse:0.22233
# [572]	validation_0-rmse:0.22234
# [573]	validation_0-rmse:0.22232
# [574]	validation_0-rmse:0.22231
# [575]	validation_0-rmse:0.22232
# [576]	validation_0-rmse:0.22232
# [577]	validation_0-rmse:0.22236
# [578]	validation_0-rmse:0.22236
# [579]	validation_0-rmse:0.22236
# [580]	validation_0-rmse:0.22232
# [581]	validation_0-rmse:0.22232
# [582]	validation_0-rmse:0.22231
# [583]	validation_0-rmse:0.22232
# [584]	validation_0-rmse:0.22232
# [585]	validation_0-rmse:0.22229
# [586]	validation_0-rmse:0.22227
# [587]	validation_0-rmse:0.22226
# [588]	validation_0-rmse:0.22224
# [589]	validation_0-rmse:0.22227
# [590]	validation_0-rmse:0.22225
# [591]	validation_0-rmse:0.22224
# [592]	validation_0-rmse:0.22223
# [593]	validation_0-rmse:0.22225
# [594]	validation_0-rmse:0.22227
# [595]	validation_0-rmse:0.22226
# [596]	validation_0-rmse:0.22224
# [597]	validation_0-rmse:0.22221
# [598]	validation_0-rmse:0.22220
# [599]	validation_0-rmse:0.22223
# [600]	validation_0-rmse:0.22225
# [601]	validation_0-rmse:0.22223
# [602]	validation_0-rmse:0.22224
# [603]	validation_0-rmse:0.22223
# [604]	validation_0-rmse:0.22224
# [605]	validation_0-rmse:0.22224
# [606]	validation_0-rmse:0.22223
# [607]	validation_0-rmse:0.22224
# [608]	validation_0-rmse:0.22226
# [609]	validation_0-rmse:0.22225
# [610]	validation_0-rmse:0.22227
# [611]	validation_0-rmse:0.22227
# [612]	validation_0-rmse:0.22228
# [613]	validation_0-rmse:0.22230
# [614]	validation_0-rmse:0.22232
# [615]	validation_0-rmse:0.22237
# [616]	validation_0-rmse:0.22237
# [617]	validation_0-rmse:0.22236
# [618]	validation_0-rmse:0.22234
# [619]	validation_0-rmse:0.22233
# [620]	validation_0-rmse:0.22234
# [621]	validation_0-rmse:0.22236
# [622]	validation_0-rmse:0.22236
# [623]	validation_0-rmse:0.22237
# [624]	validation_0-rmse:0.22236
# [625]	validation_0-rmse:0.22237
# [626]	validation_0-rmse:0.22237
# [627]	validation_0-rmse:0.22239
# [628]	validation_0-rmse:0.22239
# [629]	validation_0-rmse:0.22242
# [630]	validation_0-rmse:0.22240
# [631]	validation_0-rmse:0.22239
# [632]	validation_0-rmse:0.22239
# [633]	validation_0-rmse:0.22239
# [634]	validation_0-rmse:0.22238
# [635]	validation_0-rmse:0.22240
# [636]	validation_0-rmse:0.22240
# [637]	validation_0-rmse:0.22239
# [638]	validation_0-rmse:0.22239
# [639]	validation_0-rmse:0.22237
# [640]	validation_0-rmse:0.22237
# [641]	validation_0-rmse:0.22237
# [642]	validation_0-rmse:0.22237
# [643]	validation_0-rmse:0.22239
# [644]	validation_0-rmse:0.22240
# [645]	validation_0-rmse:0.22241
# [646]	validation_0-rmse:0.22242
# [647]	validation_0-rmse:0.22242
# [648]	validation_0-rmse:0.22240
# [649]	validation_0-rmse:0.22242
# [650]	validation_0-rmse:0.22243
# [651]	validation_0-rmse:0.22243
# [652]	validation_0-rmse:0.22243
# [653]	validation_0-rmse:0.22243
# [654]	validation_0-rmse:0.22242
# [655]	validation_0-rmse:0.22240
# [656]	validation_0-rmse:0.22241
# [657]	validation_0-rmse:0.22244
# [658]	validation_0-rmse:0.22245
# [659]	validation_0-rmse:0.22243
# [660]	validation_0-rmse:0.22242
# [661]	validation_0-rmse:0.22239
# [662]	validation_0-rmse:0.22239
# [663]	validation_0-rmse:0.22240
# [664]	validation_0-rmse:0.22239
# [665]	validation_0-rmse:0.22239
# [666]	validation_0-rmse:0.22238
# [667]	validation_0-rmse:0.22237
# [668]	validation_0-rmse:0.22237
# [669]	validation_0-rmse:0.22240
# [670]	validation_0-rmse:0.22242
# [671]	validation_0-rmse:0.22241
# [672]	validation_0-rmse:0.22241
# [673]	validation_0-rmse:0.22241
# [674]	validation_0-rmse:0.22239
# [675]	validation_0-rmse:0.22241
# [676]	validation_0-rmse:0.22242
# [677]	validation_0-rmse:0.22244
# [678]	validation_0-rmse:0.22244
# [679]	validation_0-rmse:0.22240
# [680]	validation_0-rmse:0.22240
# [681]	validation_0-rmse:0.22241
# [682]	validation_0-rmse:0.22241
# [683]	validation_0-rmse:0.22243
# [684]	validation_0-rmse:0.22241
# [685]	validation_0-rmse:0.22240
# [686]	validation_0-rmse:0.22240
# [687]	validation_0-rmse:0.22240
# [688]	validation_0-rmse:0.22240
# [689]	validation_0-rmse:0.22238
# [690]	validation_0-rmse:0.22239
# [691]	validation_0-rmse:0.22239
# [692]	validation_0-rmse:0.22238
# [693]	validation_0-rmse:0.22239
# [694]	validation_0-rmse:0.22236
# [695]	validation_0-rmse:0.22237
# [696]	validation_0-rmse:0.22236
# [697]	validation_0-rmse:0.22235
# [698]	validation_0-rmse:0.22236
# [699]	validation_0-rmse:0.22237
# [700]	validation_0-rmse:0.22237
# [701]	validation_0-rmse:0.22238
# [702]	validation_0-rmse:0.22238
# [703]	validation_0-rmse:0.22239
# [704]	validation_0-rmse:0.22240
# [705]	validation_0-rmse:0.22241
# [706]	validation_0-rmse:0.22241
# [707]	validation_0-rmse:0.22243
# [708]	validation_0-rmse:0.22243
# [709]	validation_0-rmse:0.22245
# [710]	validation_0-rmse:0.22243
# [711]	validation_0-rmse:0.22241
# [712]	validation_0-rmse:0.22243
# [713]	validation_0-rmse:0.22243
# [714]	validation_0-rmse:0.22243
# [715]	validation_0-rmse:0.22244
# [716]	validation_0-rmse:0.22246
# [717]	validation_0-rmse:0.22247
# [718]	validation_0-rmse:0.22246
# [719]	validation_0-rmse:0.22246
# [720]	validation_0-rmse:0.22245
# [721]	validation_0-rmse:0.22247
# [722]	validation_0-rmse:0.22247
# [723]	validation_0-rmse:0.22248
# [724]	validation_0-rmse:0.22248
# [725]	validation_0-rmse:0.22247
# [726]	validation_0-rmse:0.22248
# [727]	validation_0-rmse:0.22248
# [728]	validation_0-rmse:0.22249
# [729]	validation_0-rmse:0.22247
# [730]	validation_0-rmse:0.22248
# [731]	validation_0-rmse:0.22247
# [732]	validation_0-rmse:0.22246
# [733]	validation_0-rmse:0.22244
# [734]	validation_0-rmse:0.22243
# [735]	validation_0-rmse:0.22243
# [736]	validation_0-rmse:0.22243
# [737]	validation_0-rmse:0.22243
# [738]	validation_0-rmse:0.22242
# [739]	validation_0-rmse:0.22241
# [740]	validation_0-rmse:0.22240
# [741]	validation_0-rmse:0.22239
# [742]	validation_0-rmse:0.22239
# [743]	validation_0-rmse:0.22240
# [744]	validation_0-rmse:0.22240
# [745]	validation_0-rmse:0.22240
# [746]	validation_0-rmse:0.22240
# [747]	validation_0-rmse:0.22239
# [748]	validation_0-rmse:0.22239
# [749]	validation_0-rmse:0.22239
# [750]	validation_0-rmse:0.22239
# [751]	validation_0-rmse:0.22240
# [752]	validation_0-rmse:0.22240
# [753]	validation_0-rmse:0.22240
# [754]	validation_0-rmse:0.22240
# [755]	validation_0-rmse:0.22240
# [756]	validation_0-rmse:0.22240
# [757]	validation_0-rmse:0.22242
# [758]	validation_0-rmse:0.22241
# [759]	validation_0-rmse:0.22241
# [760]	validation_0-rmse:0.22242
# [761]	validation_0-rmse:0.22242
# [762]	validation_0-rmse:0.22241
# [763]	validation_0-rmse:0.22241
# [764]	validation_0-rmse:0.22241
# [765]	validation_0-rmse:0.22239
# [766]	validation_0-rmse:0.22239
# [767]	validation_0-rmse:0.22239
# [768]	validation_0-rmse:0.22239
# [769]	validation_0-rmse:0.22240
# [770]	validation_0-rmse:0.22241
# [771]	validation_0-rmse:0.22239
# [772]	validation_0-rmse:0.22239
# [773]	validation_0-rmse:0.22238
# [774]	validation_0-rmse:0.22239
# [775]	validation_0-rmse:0.22237
# [776]	validation_0-rmse:0.22238
# [777]	validation_0-rmse:0.22238
# [778]	validation_0-rmse:0.22238
# [779]	validation_0-rmse:0.22239
# [780]	validation_0-rmse:0.22238
# [781]	validation_0-rmse:0.22237
# [782]	validation_0-rmse:0.22237
# [783]	validation_0-rmse:0.22237
# [784]	validation_0-rmse:0.22236
# [785]	validation_0-rmse:0.22234
# [786]	validation_0-rmse:0.22233
# [787]	validation_0-rmse:0.22233
# [788]	validation_0-rmse:0.22232
# [789]	validation_0-rmse:0.22233
# [790]	validation_0-rmse:0.22234
# [791]	validation_0-rmse:0.22234
# [792]	validation_0-rmse:0.22233
# [793]	validation_0-rmse:0.22234
# [794]	validation_0-rmse:0.22235
# [795]	validation_0-rmse:0.22236
# [796]	validation_0-rmse:0.22236
# [797]	validation_0-rmse:0.22234
# [798]	validation_0-rmse:0.22233
# [799]	validation_0-rmse:0.22234
# [800]	validation_0-rmse:0.22232
# [801]	validation_0-rmse:0.22232
# [802]	validation_0-rmse:0.22231
# [803]	validation_0-rmse:0.22231
# [804]	validation_0-rmse:0.22232
# [805]	validation_0-rmse:0.22231
# [806]	validation_0-rmse:0.22231
# [807]	validation_0-rmse:0.22231
# [808]	validation_0-rmse:0.22231
# [809]	validation_0-rmse:0.22230
# [810]	validation_0-rmse:0.22230
# [811]	validation_0-rmse:0.22231
# [812]	validation_0-rmse:0.22230
# [813]	validation_0-rmse:0.22230
# [814]	validation_0-rmse:0.22231
# [815]	validation_0-rmse:0.22230
# [816]	validation_0-rmse:0.22230
# [817]	validation_0-rmse:0.22229
# [818]	validation_0-rmse:0.22230
# [819]	validation_0-rmse:0.22229
# [820]	validation_0-rmse:0.22230
# [821]	validation_0-rmse:0.22229
# [822]	validation_0-rmse:0.22229
# [823]	validation_0-rmse:0.22228
# [824]	validation_0-rmse:0.22227
# [825]	validation_0-rmse:0.22227
# [826]	validation_0-rmse:0.22226
# [827]	validation_0-rmse:0.22227
# [828]	validation_0-rmse:0.22226
# [829]	validation_0-rmse:0.22227
# [830]	validation_0-rmse:0.22227
# [831]	validation_0-rmse:0.22226
# [832]	validation_0-rmse:0.22226
# [833]	validation_0-rmse:0.22226
# [834]	validation_0-rmse:0.22226
# [835]	validation_0-rmse:0.22226
# [836]	validation_0-rmse:0.22226
# [837]	validation_0-rmse:0.22225
# [838]	validation_0-rmse:0.22225
# [839]	validation_0-rmse:0.22226
# [840]	validation_0-rmse:0.22225
# [841]	validation_0-rmse:0.22225
# [842]	validation_0-rmse:0.22225
# [843]	validation_0-rmse:0.22225
# [844]	validation_0-rmse:0.22224
# [845]	validation_0-rmse:0.22224
# [846]	validation_0-rmse:0.22223
# [847]	validation_0-rmse:0.22224
# [848]	validation_0-rmse:0.22224
# [849]	validation_0-rmse:0.22224
# [850]	validation_0-rmse:0.22224
# [851]	validation_0-rmse:0.22224
# [852]	validation_0-rmse:0.22224
# [853]	validation_0-rmse:0.22224
# [854]	validation_0-rmse:0.22225
# [855]	validation_0-rmse:0.22225
# [856]	validation_0-rmse:0.22225
# [857]	validation_0-rmse:0.22226
# [858]	validation_0-rmse:0.22225
# [859]	validation_0-rmse:0.22225
# [860]	validation_0-rmse:0.22226
# [861]	validation_0-rmse:0.22226
# [862]	validation_0-rmse:0.22226
# [863]	validation_0-rmse:0.22226
# [864]	validation_0-rmse:0.22226
# [865]	validation_0-rmse:0.22226
# [866]	validation_0-rmse:0.22226
# [867]	validation_0-rmse:0.22227
# [868]	validation_0-rmse:0.22226
# [869]	validation_0-rmse:0.22227
# [870]	validation_0-rmse:0.22227
# [871]	validation_0-rmse:0.22227
# [872]	validation_0-rmse:0.22228
# [873]	validation_0-rmse:0.22228
# [874]	validation_0-rmse:0.22229
# [875]	validation_0-rmse:0.22229
# [876]	validation_0-rmse:0.22229
# [877]	validation_0-rmse:0.22229
# [878]	validation_0-rmse:0.22229
# [879]	validation_0-rmse:0.22229
# [880]	validation_0-rmse:0.22229
# [881]	validation_0-rmse:0.22229
# [882]	validation_0-rmse:0.22231
# [883]	validation_0-rmse:0.22231
# [884]	validation_0-rmse:0.22231
# [885]	validation_0-rmse:0.22231
# [886]	validation_0-rmse:0.22230
# [887]	validation_0-rmse:0.22231
# [888]	validation_0-rmse:0.22231
# [889]	validation_0-rmse:0.22231
# [890]	validation_0-rmse:0.22231
# [891]	validation_0-rmse:0.22231
# [892]	validation_0-rmse:0.22231
# [893]	validation_0-rmse:0.22229
# [894]	validation_0-rmse:0.22230
# [895]	validation_0-rmse:0.22230
# [896]	validation_0-rmse:0.22230
# [897]	validation_0-rmse:0.22229
# [898]	validation_0-rmse:0.22230
# [899]	validation_0-rmse:0.22230
# [900]	validation_0-rmse:0.22230
# [901]	validation_0-rmse:0.22230
# [902]	validation_0-rmse:0.22230
# [903]	validation_0-rmse:0.22230
# [904]	validation_0-rmse:0.22230
# [905]	validation_0-rmse:0.22230
# [906]	validation_0-rmse:0.22230
# [907]	validation_0-rmse:0.22230
# [908]	validation_0-rmse:0.22230
# [909]	validation_0-rmse:0.22230
# [910]	validation_0-rmse:0.22230
# [911]	validation_0-rmse:0.22230
# [912]	validation_0-rmse:0.22231
# [913]	validation_0-rmse:0.22231
# [914]	validation_0-rmse:0.22231
# [915]	validation_0-rmse:0.22230
# [916]	validation_0-rmse:0.22230
# [917]	validation_0-rmse:0.22230
# [918]	validation_0-rmse:0.22230
# [919]	validation_0-rmse:0.22230
# [920]	validation_0-rmse:0.22230
# [921]	validation_0-rmse:0.22230
# [922]	validation_0-rmse:0.22230
# [923]	validation_0-rmse:0.22231
# [924]	validation_0-rmse:0.22231
# [925]	validation_0-rmse:0.22231
# [926]	validation_0-rmse:0.22231
# [927]	validation_0-rmse:0.22230
# [928]	validation_0-rmse:0.22230
# [929]	validation_0-rmse:0.22230
# [930]	validation_0-rmse:0.22230
# [931]	validation_0-rmse:0.22230
# [932]	validation_0-rmse:0.22230
# [933]	validation_0-rmse:0.22231
# [934]	validation_0-rmse:0.22232
# [935]	validation_0-rmse:0.22232
# [936]	validation_0-rmse:0.22232
# [937]	validation_0-rmse:0.22232
# [938]	validation_0-rmse:0.22232
# [939]	validation_0-rmse:0.22232
# [940]	validation_0-rmse:0.22232
# [941]	validation_0-rmse:0.22231
# [942]	validation_0-rmse:0.22232
# [943]	validation_0-rmse:0.22231
# [944]	validation_0-rmse:0.22231
# [945]	validation_0-rmse:0.22232
# [946]	validation_0-rmse:0.22232
# [947]	validation_0-rmse:0.22231
# [948]	validation_0-rmse:0.22231
# [949]	validation_0-rmse:0.22231
# [950]	validation_0-rmse:0.22231
# [951]	validation_0-rmse:0.22231
# [952]	validation_0-rmse:0.22231
# [953]	validation_0-rmse:0.22231
# [954]	validation_0-rmse:0.22231
# [955]	validation_0-rmse:0.22230
# [956]	validation_0-rmse:0.22230
# [957]	validation_0-rmse:0.22231
# [958]	validation_0-rmse:0.22231
# [959]	validation_0-rmse:0.22230
# [960]	validation_0-rmse:0.22230
# [961]	validation_0-rmse:0.22230
# [962]	validation_0-rmse:0.22230
# [963]	validation_0-rmse:0.22230
# [964]	validation_0-rmse:0.22230
# [965]	validation_0-rmse:0.22230
# [966]	validation_0-rmse:0.22230
# [967]	validation_0-rmse:0.22230
# [968]	validation_0-rmse:0.22230
# [969]	validation_0-rmse:0.22230
# [970]	validation_0-rmse:0.22229
# [971]	validation_0-rmse:0.22229
# [972]	validation_0-rmse:0.22229
# [973]	validation_0-rmse:0.22229
# [974]	validation_0-rmse:0.22229
# [975]	validation_0-rmse:0.22230
# [976]	validation_0-rmse:0.22230
# [977]	validation_0-rmse:0.22230
# [978]	validation_0-rmse:0.22230
# [979]	validation_0-rmse:0.22230
# [980]	validation_0-rmse:0.22230
# [981]	validation_0-rmse:0.22230
# [982]	validation_0-rmse:0.22230
# [983]	validation_0-rmse:0.22230
# [984]	validation_0-rmse:0.22230
# [985]	validation_0-rmse:0.22230
# [986]	validation_0-rmse:0.22230
# [987]	validation_0-rmse:0.22230
# [988]	validation_0-rmse:0.22230
# [989]	validation_0-rmse:0.22230
# [990]	validation_0-rmse:0.22230
# [991]	validation_0-rmse:0.22230
# [992]	validation_0-rmse:0.22230
# [993]	validation_0-rmse:0.22230
# [994]	validation_0-rmse:0.22230
# [995]	validation_0-rmse:0.22230
# [996]	validation_0-rmse:0.22230
# [997]	validation_0-rmse:0.22229
# [998]	validation_0-rmse:0.22230
# [999]	validation_0-rmse:0.22229
# 0.2266710794842377 0.2218613

# %%
np.mean(rmses), np.mean(max_abss)
# Out:
# (0.20496054273763473, 0.6972420012032337)

# %%
model.estimators[-1]['lgbm'].predict(X_test)[0], model.estimators[-1]['cat'].predict(X_test)[0]
# Out:
# (0.4639054303623368, 0.46283330173793175)

# %% [markdown]
# # Test

# %%
y_pred = model.predict(X_test)
root_mean_squared_error(y_test, y_pred), max(abs(y_test-y_pred)), r2_score(y_test, y_pred)
# Out:
# (0.2389690996545034, 1.1360798030933892, 0.6369704834577166)

# %%
for y_pred in model.predict_sep(X_test):
    print(root_mean_squared_error(y_test, y_pred), max(abs(y_test-y_pred)), r2_score(y_test, y_pred))
# Out:
# 0.24397216018532294 1.1152827364388536 0.6216105791266331
# 0.23381230252259894 1.3122396122688627 0.6524693119917896
# 0.23916510883448522 1.1807685248849886 0.6363747051710279

# %%
np.sum((y_test >= 0) == (y_pred >= 0)) / len(y_pred)

# %% [markdown]
# (0.20189549398215334, 0.8893085024191398, 0.2079495875486005)
# antes

# %%
for local_model in model.estimators:
    y_pred = local_model['lgbm'].predict(X_test)
    #print(root_mean_squared_error(y_test, y_pred), max(abs(y_test-y_pred)))

# %%
import shap

explainer = shap.TreeExplainer(model.estimators[-1]['lgbm'])
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test, X_test.columns, plot_size=0.3, max_display=50)

# %%
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# compute SHAP values
explainer = shap.Explainer(model.estimators[-1]['lgbm'], feature_perturbation="tree_path_dependent")
shap_values = explainer(X_test)

index = 508

print(f"Predicted {y_pred[index]: .4f} True:{y_test[index]: .4f}")
shap.plots.waterfall(shap_values[index], max_display=20)
X_test.iloc[index]
# Out:
# Predicted  0.1585 True: 0.2380
# Brocha                                       011.0114.300
# NBrochasHSS                                             2
# NDiscos                                                 2
# NUsos                                                  16
# USDutchman                                             12
#                                                  ...
# Maquina_BrochaSN_NBrochasHSStargetC_lag1           -0.003
# Maquina_BrochaSN_NBrochasHSStargetC_lag3            0.022
# Maquina_BrochaSN_NBrochasHSStargetC_lag7            0.003
# Maquina_BrochaSN_NBrochasHSStargetC_lag14          -0.013
# Maquina_BrochaSN_NBrochasHSStargetC_lag30          -0.016
# Name: 508, Length: 1499, dtype: object
